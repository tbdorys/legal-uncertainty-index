# %% [markdown]
# **Author:** Dorys Trujillo
# **Project:** Legal Uncertainty Index (IIJ)
# **Data Source:** Ministry of Commerce, Industry and Tourism (MinCIT)
# **Period:** 2018–2025

# %% [markdown]
# #### Environment Setup and Configuration
#
# This block initializes the computational environment required for the OCR preprocessing pipeline. It imports all necessary libraries for PDF handling, image processing, optical character recognition, and data management. It also defines the project directory structure (input, output, and manifest locations), establishes OCR and table-detection parameters, and ensures that required output directories exist.
#
# By centralizing configuration parameters and path definitions, this block guarantees reproducibility, structural consistency, and full separation between raw and processed data.

# %%
# Imports

from pathlib import Path
from datetime import datetime
import hashlib
#import json
import re
import shutil

import numpy as np
import pandas as pd

import fitz  # PyMuPDF
import cv2
import pytesseract

# %%
# Paths

from pathlib import Path

# Set project root (works from notebooks folder)
PROJECT_ROOT = Path().resolve().parent

# Main project paths
DATA_RAW = PROJECT_ROOT / "data_raw"
DATA_PROCESSED = PROJECT_ROOT / "data_processed"
MANIFESTS = PROJECT_ROOT / "manifests"
NOTEBOOKS = PROJECT_ROOT / "notebooks"

# Source and output roots for this pipeline
RAW_ROOT = DATA_RAW
OUT_ROOT = DATA_PROCESSED / "pdf_ocr"

# Manifest paths
DOWNLOADS_MANIFEST = MANIFESTS / "downloads_manifest.csv"
OCR_MANUAL_RULES = MANIFESTS / "ocr_manual_rules.csv"
MANIFEST_MASTER = MANIFESTS / "manifest_ocr.csv"

# OCR configuration
TESSERACT_EXE = r"C:\Program Files\Tesseract-OCR\tesseract.exe"
OCR_LANG = "spa+eng"
OCR_DPI = 300
QUICK_DPI = 120  # fast rendering for annex/table detection

# Annex/table detection thresholds
LD_THRESHOLD = 0.020
ANNEX_MIN_CONSEC = 2
ANNEX_MIN_FRAC_REST = 0.60
ANNEX_MIN_START_FRAC = 0.50

# Setup
pytesseract.pytesseract.tesseract_cmd = TESSERACT_EXE
OUT_ROOT.mkdir(parents=True, exist_ok=True)
MANIFESTS.mkdir(parents=True, exist_ok=True)

if not RAW_ROOT.exists():
    raise FileNotFoundError(f"RAW_ROOT not found: {RAW_ROOT}")

if not OCR_MANUAL_RULES.exists():
    raise FileNotFoundError(f"OCR_MANUAL_RULES not found: {OCR_MANUAL_RULES}")

print("PROJECT_ROOT:", PROJECT_ROOT)
print("RAW_ROOT:", RAW_ROOT)
print("OUT_ROOT:", OUT_ROOT)
print("DOWNLOADS_MANIFEST:", DOWNLOADS_MANIFEST)
print("OCR_MANUAL_RULES:", OCR_MANUAL_RULES)
print("MANIFEST_MASTER:", MANIFEST_MASTER)
# Out:
# PROJECT_ROOT: C:\Users\dtruj\Documentos\proyectos\legal-uncertainty-index
# RAW_ROOT: C:\Users\dtruj\Documentos\proyectos\legal-uncertainty-index\data_raw
# OUT_ROOT: C:\Users\dtruj\Documentos\proyectos\legal-uncertainty-index\data_processed\pdf_ocr
# DOWNLOADS_MANIFEST: C:\Users\dtruj\Documentos\proyectos\legal-uncertainty-index\manifests\downloads_manifest.csv
# OCR_MANUAL_RULES: C:\Users\dtruj\Documentos\proyectos\legal-uncertainty-index\manifests\ocr_manual_rules.csv
# MANIFEST_MASTER: C:\Users\dtruj\Documentos\proyectos\legal-uncertainty-index\manifests\manifest_ocr.csv

# %% [markdown]
# #### Utility Functions for File Integrity and Structure Management
#
# This block defines auxiliary functions that support file traceability, structural consistency, and systematic document processing. It includes routines to compute SHA-256 hashes for integrity verification, extract year identifiers from file paths for structured output organization, and recursively enumerate all PDF files within the raw data directory. These utilities ensure full document coverage, reproducibility, and transparent linkage between input and processed outputs without performing any content-level transformations.
#
# In addition, the pipeline incorporates a manual decision table (ocr_manual_rules.csv) that captures document-level interventions identified through prior inspection. This table specifies whether a document should be excluded or partially processed (e.g., truncated to a defined page range) when it contains non-relevant content such as extensive annexes. By externalizing these decisions, the workflow maintains methodological transparency, preserves the integrity of raw data, and ensures that all deviations from the standard processing logic are explicitly documented and reproducible.

# %%
# Utility functions: hashing, year extraction, and file listing

YEAR_RE = re.compile(r"(20(1[8-9]|2[0-5]))")

def sha256_file(path: Path) -> str:
    # Compute SHA-256 hash for file integrity verification
    h = hashlib.sha256()
    with path.open("rb") as f:
        for chunk in iter(lambda: f.read(1024 * 1024), b""):
            h.update(chunk)
    return h.hexdigest()

def find_year(pdf_path: Path) -> str:
    # Extract year from folder structure: data_raw/{year}/file.pdf
    try:
        return pdf_path.relative_to(RAW_ROOT).parts[0]
    except Exception:
        return "unknown_year"

def list_pdfs(root: Path) -> list[Path]:
    # Recursively list all PDF files under the given root directory
    return sorted(root.rglob("*.pdf"))

# %%
# Manual decision rules

def load_manual_rules(path: Path) -> dict:
    """
    Load OCR manual rules and return a dict indexed by doc_id.
    """
    df = pd.read_csv(path, sep=";", dtype={"doc_id": str})

    # Normalize
    df["doc_id"] = df["doc_id"].astype(str).str.strip()
    df["action"] = df["action"].astype(str).str.strip().str.lower()

    # Optional fields (avoid NaNs)
    for col in ["reason", "reviewed_by", "review_date", "notes"]:
        if col in df.columns:
            df[col] = df[col].fillna("").astype(str).str.strip()

    # Convert to dict for fast lookup
    rules = df.set_index("doc_id").to_dict(orient="index")

    return rules


# Load once
MANUAL_RULES = load_manual_rules(OCR_MANUAL_RULES)

print("Manual rules loaded:", len(MANUAL_RULES))

# Quick check (optional)
sample_keys = list(MANUAL_RULES.keys())[:3]
for k in sample_keys:
    print(k, "->", MANUAL_RULES[k])
# Out:
# Manual rules loaded: 3
# id_0150 -> {'action': 'exclude', 'page_start': nan, 'page_end': nan, 'reason': 'Documento no relevante', 'review_date': '06/04/2026', 'notes': 'Documento muy extenso, no corresponde a proyecto'}
# id_0241 -> {'action': 'truncate', 'page_start': 1.0, 'page_end': 9.0, 'reason': 'Anexo extenso desde pág. 10', 'review_date': '06/04/2026', 'notes': 'Solo primeras páginas contienen articulado'}
# id_0284 -> {'action': 'truncate', 'page_start': 1.0, 'page_end': 14.0, 'reason': 'Anexo extenso', 'review_date': '06/04/2026', 'notes': 'Resto son tablas'}

# %% [markdown]
# #### Table-Like Page Detection
#
# This block performs image-based structural analysis to identify table-like pages within each PDF. Pages are rendered at low resolution, processed to detect horizontal and vertical line patterns, and classified using a line-density threshold. The resulting page-level indicators are later used to determine whether a table-based annex exists at the end of the document.

# %%
# Table-like page detection based on image analysis

def render_page_gray(page: fitz.Page, dpi: int = 120) -> np.ndarray:
    # Render a PDF page to a grayscale image at the specified resolution
    zoom = dpi / 72.0
    mat = fitz.Matrix(zoom, zoom)
    pix = page.get_pixmap(matrix=mat, alpha=False)
    img = np.frombuffer(pix.samples, dtype=np.uint8).reshape(pix.height, pix.width, pix.n)
    if img.shape[2] == 4:
        img = img[:, :, :3]
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    return gray

def compute_line_density(gray: np.ndarray) -> float:
    # Estimate structural line density to identify table-like layouts
    bw = cv2.adaptiveThreshold(
        gray, 255,
        cv2.ADAPTIVE_THRESH_MEAN_C,
        cv2.THRESH_BINARY_INV,
        25, 15
    )
    h_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (40, 1))
    v_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (1, 40))
    h = cv2.morphologyEx(bw, cv2.MORPH_OPEN, h_kernel, iterations=1)
    v = cv2.morphologyEx(bw, cv2.MORPH_OPEN, v_kernel, iterations=1)
    lines = cv2.bitwise_or(h, v)
    return float((lines.sum() / 255.0) / (lines.shape[0] * lines.shape[1]))

def detect_table_like_pages(pdf_path: Path, quick_dpi=120, ld_threshold=0.02):
    # Identify pages exhibiting high line density consistent with tabular structures
    doc = fitz.open(str(pdf_path))
    flags, densities = [], []
    for i in range(doc.page_count):
        page = doc.load_page(i)
        gray = render_page_gray(page, dpi=quick_dpi)
        ld = compute_line_density(gray)
        flags.append(ld >= ld_threshold)
        densities.append(ld)
    n_pages = doc.page_count
    doc.close()
    return flags, densities, n_pages

# %% [markdown]
# #### Annex Cutoff Detection
#
# This block analyzes the sequence of table-like page indicators to determine whether a structured annex composed primarily of tables exists at the end of the document. It applies conservative criteria based on page position, minimum consecutive table-like pages, and predominance toward the document’s end. The output is a cutoff page index or None, indicating whether an annex should be removed.

# %%
# Detect annex cutoff point based on table-like patterns at the end of the document

def detect_annex_cutoff(
    table_flags: list[bool],
    min_consec=2,
    min_frac_rest=0.60,
    min_start_frac=0.50
):
    # Determine the page index where annex-like content begins
    n = len(table_flags)
    if n < 6:
        return None

    # Restrict cutoff search to the second half of the document
    start_min = int(n * min_start_frac)

    for i in range(start_min, n):
        if not table_flags[i]:
            continue

        # Count consecutive table-like pages starting at position i
        consec = 1
        j = i + 1
        while j < n and table_flags[j]:
            consec += 1
            j += 1

        # Validate minimum consecutive pages and overall table density
        if consec >= min_consec:
            rest = table_flags[i:]
            frac = sum(rest) / len(rest)
            if frac >= min_frac_rest:
                return i + 1  # Return 1-indexed page number

    return None

# %% [markdown]
# #### Truncated PDF Generation
#
# This block creates a cleaned version of the document when an annex cutoff has been detected. It generates a new PDF containing only the relevant pages (from the beginning up to the cutoff point), effectively removing the table-based annex at the end. This truncated document becomes the standardized input for subsequent OCR processing.

# %%
# Save truncated PDF up to the detected annex cutoff

def save_truncated_pdf(input_pdf: Path, output_pdf: Path, cutoff_page_1indexed: int):
    # Create a new PDF containing pages prior to the cutoff
    src = fitz.open(str(input_pdf))
    dst = fitz.open()

    last_keep = cutoff_page_1indexed - 1
    if last_keep < 1:
        src.close()
        dst.close()
        raise ValueError("Invalid cutoff: would remove entire document.")

    # Insert pages from the beginning up to the last page to retain
    dst.insert_pdf(src, from_page=0, to_page=last_keep - 1)

    # Ensure destination directory exists before saving
    output_pdf.parent.mkdir(parents=True, exist_ok=True)
    dst.save(str(output_pdf))

    dst.close()
    src.close()

# %% [markdown]
# #### Page-Level OCR Processing
#
# This block performs optical character recognition (OCR) on the cleaned PDF document, processing each page individually. Pages are rendered as images, minimally preprocessed to enhance legibility, and passed to Tesseract to extract text. The resulting page-level outputs are concatenated into a structured text representation for downstream analysis.

# %%
# Perform page-level OCR on the processed PDF

def ocr_pdf_to_text(pdf_path: Path, dpi: int, lang: str) -> str:
    # Extract text from each page using Tesseract OCR
    doc = fitz.open(str(pdf_path))
    parts = []

    for i in range(doc.page_count):
        page = doc.load_page(i)
        gray = render_page_gray(page, dpi=dpi)

        # Basic image preprocessing to enhance OCR accuracy
        gray = cv2.normalize(gray, None, 0, 255, cv2.NORM_MINMAX)
        bw = cv2.adaptiveThreshold(
            gray, 255,
            cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
            cv2.THRESH_BINARY,
            31, 11
        )

        # Tesseract configuration: LSTM engine with uniform text layout
        config = "--oem 3 --psm 6"
        try:
            txt = pytesseract.image_to_string(bw, lang=lang, config=config).strip()
        except Exception as e:
            txt = f"[OCR_ERROR: {str(e)}]"
        # Append page header for traceability
        parts.append(f"\n### Page {i+1}\n{txt}")

    doc.close()
    return "\n".join(parts).strip()

# %% [markdown]
# #### Single-Document Processing Pipeline
#
# This block orchestrates the complete processing workflow for a single PDF file. It detects potential annexes, generates a cleaned version of the document (if required), applies OCR to the resulting PDF, and produces both page-level text output and detailed metadata records. The block ensures structural consistency, reproducibility, and full traceability for each processed document.

# %%
# Process a single PDF end-to-end (annex detection, optional truncation, OCR, and per-file manifest)

from pathlib import Path
import json

def process_one_pdf(pdf_path: Path) -> dict:
    ts = datetime.utcnow().isoformat(timespec="seconds") + "Z"
    sha_in = sha256_file(pdf_path)

    # Derive year and relative input path from the raw directory structure
    rel_path = pdf_path.relative_to(RAW_ROOT)          # e.g., 2018/Document.pdf
    input_rel = rel_path.as_posix()                    # e.g., "2018/Document.pdf"
    year_dir = rel_path.parts[0]                       # e.g., "2018"
    base_name = pdf_path.stem                          # Filename without extension
    
    doc_id = base_name
    manual_rule = MANUAL_RULES.get(doc_id)

    # Define per-year output layout
    out_year_dir = OUT_ROOT / year_dir
    out_pdf_dir = out_year_dir / "pdf"
    out_txt_dir = out_year_dir / "txt"
    out_json_dir = out_year_dir / "json"

    out_pdf_dir.mkdir(parents=True, exist_ok=True)
    out_txt_dir.mkdir(parents=True, exist_ok=True)
    out_json_dir.mkdir(parents=True, exist_ok=True)

    # Define output file paths (no per-document subdirectories)
    out_pdf_final = out_pdf_dir / f"{base_name}.pdf"
    out_txt = out_txt_dir / f"{base_name}.txt"
    out_manifest = out_json_dir / f"{base_name}.json"

    # Determine total pages
    doc = fitz.open(str(pdf_path))
    n_pages = doc.page_count
    doc.close()
    
    # Apply manual rules if available, otherwise fallback to automatic detection
    if manual_rule is not None:
        action = manual_rule["action"]
    
        if action == "exclude":
            return {
                "timestamp_utc": ts,
                "year": year_dir,
                "input_rel": input_rel,
                "input_pdf": str(pdf_path),
                "sha256_in": sha_in,
                "output_dir": "",
                "output_pdf_final": "",
                "sha256_out": "",
                "output_text": "",
                "pages_total": n_pages,
                "cutoff_page_1indexed": "",
                "pages_kept": 0,
                "pages_removed": n_pages,
                "action_pdf": "excluded_manual",
                "ocr_lang": OCR_LANG,
                "ocr_dpi": OCR_DPI,
                "status": "excluded",
                "error": ""
            }
    
        elif action == "truncate":
            cutoff = int(manual_rule["page_end"]) + 1
            table_flags, line_densities = None, None
    
        else:
            cutoff = None
            table_flags, line_densities = None, None
    
    else:
        # Automatic annex detection
        table_flags, line_densities, _ = detect_table_like_pages(
            pdf_path, quick_dpi=QUICK_DPI, ld_threshold=LD_THRESHOLD
        )
        cutoff = detect_annex_cutoff(
            table_flags,
            min_consec=ANNEX_MIN_CONSEC,
            min_frac_rest=ANNEX_MIN_FRAC_REST,
            min_start_frac=ANNEX_MIN_START_FRAC
        )

    # Produce the final PDF (either copied as-is or truncated before annex pages)
    if cutoff is None:
        shutil.copy2(pdf_path, out_pdf_final)
        pages_kept = n_pages
        pages_removed = 0
        action_pdf = "copied_no_cut"
    else:
        save_truncated_pdf(pdf_path, out_pdf_final, cutoff_page_1indexed=cutoff)
        pages_kept = cutoff - 1
        pages_removed = n_pages - pages_kept
        
        if manual_rule is not None and manual_rule["action"] == "truncate":
            action_pdf = "truncated_manual"
        else:
            action_pdf = "cut_annex_tables"
            
    # Run OCR on the final PDF and persist the extracted text
    text = ocr_pdf_to_text(out_pdf_final, dpi=OCR_DPI, lang=OCR_LANG)
    out_txt.write_text(text, encoding="utf-8", errors="ignore")

    sha_out = sha256_file(out_pdf_final)

    # Persist a per-document JSON manifest for traceability and diagnostics
    manifest = {
        "timestamp_utc": ts,
        "year": year_dir,
        "doc_id": doc_id,
        "manual_rule": manual_rule,
        "decision_source": "manual" if manual_rule is not None else "automatic",
        "input_pdf": str(pdf_path),
        "input_rel": input_rel,
        "sha256_in": sha_in,
        "output_dir": str(out_year_dir),
        "output_pdf_final": str(out_pdf_final),
        "sha256_out": sha_out,
        "output_text": str(out_txt),
        "pages_total": n_pages,
        "cutoff_page_1indexed": cutoff,
        "pages_kept": pages_kept,
        "pages_removed": pages_removed,
        "action_pdf": action_pdf,
        "ocr": {"lang": OCR_LANG, "dpi": OCR_DPI},
        "table_detection": {
            "quick_dpi": QUICK_DPI,
            "ld_threshold": LD_THRESHOLD,
            "line_densities": line_densities,
            "table_flags": table_flags
        }
    }
    out_manifest.write_text(
        json.dumps(manifest, ensure_ascii=False, indent=2),
        encoding="utf-8"
    )

    # Return a single-row summary for the master manifest
    row = {
        "timestamp_utc": ts,
        "year": year_dir,
        "doc_id": doc_id,
        "decision_source": "manual" if manual_rule is not None else "automatic",
        "input_rel": input_rel,
        "input_pdf": str(pdf_path),
        "sha256_in": sha_in,
        "output_dir": str(out_year_dir),
        "output_pdf_final": str(out_pdf_final),
        "sha256_out": sha_out,
        "output_text": str(out_txt),
        "pages_total": n_pages,
        "cutoff_page_1indexed": cutoff,
        "pages_kept": pages_kept,
        "pages_removed": pages_removed,
        "action_pdf": action_pdf,
        "manual_action": manual_rule["action"] if manual_rule is not None else "",
        "manual_page_end": manual_rule["page_end"] if manual_rule is not None else "",
        "ocr_lang": OCR_LANG,
        "ocr_dpi": OCR_DPI,
        "status": "ok",
        "error": ""
    }
    return row

# %% [markdown]
# #### Batch Processing and Master Manifest Generation
#
# This block orchestrates the complete processing workflow for a single PDF file. It derives document-level metadata, checks for manually defined rules (e.g., exclusion or truncation), and otherwise applies automated annex detection based on table-like page patterns to generate a cleaned version of the document.
#
# The resulting PDF is processed through page-level OCR, and both the extracted text and a JSON manifest are stored. This design ensures consistency, reproducibility, and full traceability by distinguishing between manual and automatic processing decisions.

# %%
# Run OCR processing for all PDFs and compile a master manifest

def run_all_pdfs(root: Path) -> pd.DataFrame:
    # Process every PDF found under the raw data root
    pdfs = list_pdfs(root)
    rows = []

    for i, pdf_path in enumerate(pdfs, start=1):
        print(f"[{i}/{len(pdfs)}] Processing: {pdf_path.name}")
        try:
            row = process_one_pdf(pdf_path)
            rows.append(row)
        except Exception as e:
            # Register processing errors without stopping the full pipeline
            row = {
                "timestamp_utc": datetime.utcnow().isoformat(timespec="seconds") + "Z",
                "year": find_year(pdf_path),
                "doc_id": pdf_path.stem,
                "decision_source": "",
                "input_rel": pdf_path.relative_to(RAW_ROOT).as_posix(),
                "input_pdf": str(pdf_path),
                "sha256_in": "",
                "output_dir": "",
                "output_pdf_final": "",
                "sha256_out": "",
                "output_text": "",
                "pages_total": "",
                "cutoff_page_1indexed": "",
                "pages_kept": "",
                "pages_removed": "",
                "action_pdf": "",
                "manual_action": "",
                "manual_page_end": "",
                "ocr_lang": OCR_LANG,
                "ocr_dpi": OCR_DPI,
                "status": "error",
                "error": str(e)
            }
            rows.append(row)

    # Build and persist master manifest
    df = pd.DataFrame(rows)
    df.to_csv(MANIFEST_MASTER, index=False, encoding="utf-8")

    print("\nProcessing completed.")
    print("Master manifest saved to:", MANIFEST_MASTER)
    print(df["status"].value_counts(dropna=False))

    return df

# %%
df_ocr = run_all_pdfs(RAW_ROOT)
# Out:
# [1/335] Processing: id_0001.pdf
# [2/335] Processing: id_0002.pdf
# [3/335] Processing: id_0003.pdf
# [4/335] Processing: id_0004.pdf
# [5/335] Processing: id_0005.pdf
# [6/335] Processing: id_0006.pdf
# [7/335] Processing: id_0007.pdf
# [8/335] Processing: id_0008.pdf
# [9/335] Processing: id_0009.pdf
# [10/335] Processing: id_0010.pdf
# [11/335] Processing: id_0011.pdf
# [12/335] Processing: id_0012.pdf
# [13/335] Processing: id_0013.pdf
# [14/335] Processing: id_0014.pdf
# [15/335] Processing: id_0015.pdf
# [16/335] Processing: id_0016.pdf
# [17/335] Processing: id_0017.pdf
# [18/335] Processing: id_0018.pdf
# [19/335] Processing: id_0019.pdf
# %%
# Execute the full OCR pipeline and load the resulting master manifest into memory
#df_ocr = run_all_pdfs(RAW_ROOT)
# Display the first rows for verification
df_ocr.head()
# Out:
#           timestamp_utc  year   doc_id decision_source         input_rel  \
# 0  2026-04-07T09:17:14Z  2018  id_0001       automatic  2018/id_0001.pdf
# 1  2026-04-07T09:17:28Z  2018  id_0002       automatic  2018/id_0002.pdf
# 2  2026-04-07T09:17:40Z  2018  id_0003       automatic  2018/id_0003.pdf
# 3  2026-04-07T09:17:51Z  2018  id_0004       automatic  2018/id_0004.pdf
# 4  2026-04-07T09:18:17Z  2018  id_0005       automatic  2018/id_0005.pdf
#
#                                            input_pdf  \
# 0  C:\Users\dtruj\Documentos\proyectos\legal-unce...
# 1  C:\Users\dtruj\Documentos\proyectos\legal-unce...
# 2  C:\Users\dtruj\Documentos\proyectos\legal-unce...
# 3  C:\Users\dtruj\Documentos\proyectos\legal-unce...
# 4  C:\Users\dtruj\Documentos\proyectos\legal-unce...
#
#                                            sha256_in  \
# 0  6a4c1f86c31095e15218cd7ddf542f5d7ec37302a14f8f...
# 1  2286e4f9ab889016aa5d3ae12a8bcf4aece00373a18556...
# 2  e40e25c444bce0b79a68ba50653fbf5d3e411d9edd35f1...
# 3  b762b3fcb91f2055e35594e925691b6156efac4cbf72c0...
# 4  719d6a02f8baf19555445e3d576953ddbe22c0cc29bf89...
#
#                                           output_dir  \
# 0  C:\Users\dtruj\Documentos\proyectos\legal-unce...
# 1  C:\Users\dtruj\Documentos\proyectos\legal-unce...
# 2  C:\Users\dtruj\Documentos\proyectos\legal-unce...
# 3  C:\Users\dtruj\Documentos\proyectos\legal-unce...
# 4  C:\Users\dtruj\Documentos\proyectos\legal-unce...
#
#                                     output_pdf_final  \
# 0  C:\Users\dtruj\Documentos\proyectos\legal-unce...
# 1  C:\Users\dtruj\Documentos\proyectos\legal-unce...
# 2  C:\Users\dtruj\Documentos\proyectos\legal-unce...
# 3  C:\Users\dtruj\Documentos\proyectos\legal-unce...
# 4  C:\Users\dtruj\Documentos\proyectos\legal-unce...
#
#                                           sha256_out  ...  \
# 0  6a4c1f86c31095e15218cd7ddf542f5d7ec37302a14f8f...  ...
# 1  3fed9818a8c402e718aa85bc4af272a83192bd8f6cde5d...  ...
# 2  e40e25c444bce0b79a68ba50653fbf5d3e411d9edd35f1...  ...
# 3  b762b3fcb91f2055e35594e925691b6156efac4cbf72c0...  ...
# 4  719d6a02f8baf19555445e3d576953ddbe22c0cc29bf89...  ...
#
#   cutoff_page_1indexed  pages_kept pages_removed        action_pdf  \
# 0                 None          10             0     copied_no_cut
# 1                    8           7             8  cut_annex_tables
# 2                 None           5             0     copied_no_cut
# 3                 None          16             0     copied_no_cut
# 4                 None           4             0     copied_no_cut
#
#    manual_action manual_page_end ocr_lang ocr_dpi status  error
# 0                                 spa+eng     300     ok
# 1                                 spa+eng     300     ok
# 2                                 spa+eng     300     ok
# 3                                 spa+eng     300     ok
# 4                                 spa+eng     300     ok
#
# [5 rows x 22 columns]
