# %% [markdown]
# **Author:** Dorys Trujillo
# **Project:** Legal Uncertainty Index (IIJ)
# **Data Source:** Ministry of Commerce, Industry and Tourism (MinCIT)
# **Period:** 2018–2025

# %% [markdown]
# #### Environment Setup and Configuration
#
# This block initializes the computational environment required for the OCR preprocessing pipeline. It imports all necessary libraries for PDF handling, image processing, optical character recognition, and data management. It also defines the project directory structure (input, output, and manifest locations), establishes OCR and table-detection parameters, and ensures that required output directories exist.
#
# By centralizing configuration parameters and path definitions, this block guarantees reproducibility, structural consistency, and full separation between raw and processed data.

# %%
##### IMPORTS ######
from pathlib import Path
from datetime import datetime
import hashlib
#import json
import re
import shutil

import numpy as np
import pandas as pd

import fitz  # PyMuPDF
import cv2
import pytesseract

# %%
# Paths
PROJECT_ROOT = Path(r"C:\Users\dtruj\Documentos\proyectos\legal-uncertainty-index")
RAW_ROOT = PROJECT_ROOT / "data_raw" / "mincit"
OUT_ROOT = PROJECT_ROOT / "data_processed" / "mincit" / "pdf_ocr"

# Master manifest (under OCR output root)
MANIFEST_DIR = OUT_ROOT / "manifests"
MANIFEST_MASTER = MANIFEST_DIR / "manifest_ocr.csv"

# OCR configuration
TESSERACT_EXE = r"C:\Program Files\Tesseract-OCR\tesseract.exe"
OCR_LANG = "spa+eng"
OCR_DPI = 300
QUICK_DPI = 120  # fast rendering for annex/table detection

# Annex/table detection thresholds
LD_THRESHOLD = 0.020
ANNEX_MIN_CONSEC = 2
ANNEX_MIN_FRAC_REST = 0.60
ANNEX_MIN_START_FRAC = 0.50

# Setup
pytesseract.pytesseract.tesseract_cmd = TESSERACT_EXE
OUT_ROOT.mkdir(parents=True, exist_ok=True)
MANIFEST_DIR.mkdir(parents=True, exist_ok=True)

if not RAW_ROOT.exists():
    raise FileNotFoundError(f"RAW_ROOT not found: {RAW_ROOT}")

# Master manifest schema
MANIFEST_COLUMNS = [
    "timestamp_utc","year","input_rel","input_pdf","sha256_in","output_dir",
    "output_pdf_final","sha256_out","output_text","pages_total","cutoff_page_1indexed",
    "pages_kept","pages_removed","action_pdf","ocr_lang","ocr_dpi","status","error"
]

print("RAW_ROOT:", RAW_ROOT)
print("OUT_ROOT:", OUT_ROOT)
print("MANIFEST_MASTER:", MANIFEST_MASTER)
# Out:
# RAW_ROOT: C:\Users\dtruj\Documentos\proyectos\legal-uncertainty-index\data_raw\mincit
# OUT_ROOT: C:\Users\dtruj\Documentos\proyectos\legal-uncertainty-index\data_processed\mincit\pdf_ocr
# MANIFEST_MASTER: C:\Users\dtruj\Documentos\proyectos\legal-uncertainty-index\data_processed\mincit\pdf_ocr\manifests\manifest_ocr.csv

# %% [markdown]
# #### Utility Functions for File Integrity and Structure Management
#
# This block defines auxiliary functions that support file traceability, structural consistency, and systematic document processing. It includes routines to compute SHA-256 hashes for integrity verification, extract year identifiers from file paths for structured output organization, and recursively enumerate all PDF files within the raw data directory.
#
# These utilities ensure full document coverage, reproducibility, and transparent linkage between input and processed outputs without performing any content-level transformations.

# %%
# Utility functions: hashing, year extraction, and file listing

YEAR_RE = re.compile(r"(20(1[8-9]|2[0-5]))")

def sha256_file(path: Path) -> str:
    # Compute SHA-256 hash for file integrity verification
    h = hashlib.sha256()
    with path.open("rb") as f:
        for chunk in iter(lambda: f.read(1024 * 1024), b""):
            h.update(chunk)
    return h.hexdigest()

def find_year(pdf_path: Path) -> str:
    # Extract year from file path using predefined pattern
    m = YEAR_RE.search(str(pdf_path))
    return m.group(1) if m else "unknown_year"

def list_pdfs(root: Path) -> list[Path]:
    # Recursively list all PDF files under the given root directory
    return sorted(root.rglob("*.pdf"))

# %% [markdown]
# #### Table-Like Page Detection
#
# This block performs image-based structural analysis to identify table-like pages within each PDF. Pages are rendered at low resolution, processed to detect horizontal and vertical line patterns, and classified using a line-density threshold. The resulting page-level indicators are later used to determine whether a table-based annex exists at the end of the document.

# %%
# Table-like page detection based on image analysis

def render_page_gray(page: fitz.Page, dpi: int = 120) -> np.ndarray:
    # Render a PDF page to a grayscale image at the specified resolution
    zoom = dpi / 72.0
    mat = fitz.Matrix(zoom, zoom)
    pix = page.get_pixmap(matrix=mat, alpha=False)
    img = np.frombuffer(pix.samples, dtype=np.uint8).reshape(pix.height, pix.width, pix.n)
    if img.shape[2] == 4:
        img = img[:, :, :3]
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    return gray

def compute_line_density(gray: np.ndarray) -> float:
    # Estimate structural line density to identify table-like layouts
    bw = cv2.adaptiveThreshold(
        gray, 255,
        cv2.ADAPTIVE_THRESH_MEAN_C,
        cv2.THRESH_BINARY_INV,
        25, 15
    )
    h_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (40, 1))
    v_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (1, 40))
    h = cv2.morphologyEx(bw, cv2.MORPH_OPEN, h_kernel, iterations=1)
    v = cv2.morphologyEx(bw, cv2.MORPH_OPEN, v_kernel, iterations=1)
    lines = cv2.bitwise_or(h, v)
    return float((lines.sum() / 255.0) / (lines.shape[0] * lines.shape[1]))

def detect_table_like_pages(pdf_path: Path, quick_dpi=120, ld_threshold=0.02):
    # Identify pages exhibiting high line density consistent with tabular structures
    doc = fitz.open(str(pdf_path))
    flags, densities = [], []
    for i in range(doc.page_count):
        page = doc.load_page(i)
        gray = render_page_gray(page, dpi=quick_dpi)
        ld = compute_line_density(gray)
        flags.append(ld >= ld_threshold)
        densities.append(ld)
    n_pages = doc.page_count
    doc.close()
    return flags, densities, n_pages

# %% [markdown]
# #### Annex Cutoff Detection
#
# This block analyzes the sequence of table-like page indicators to determine whether a structured annex composed primarily of tables exists at the end of the document. It applies conservative criteria based on page position, minimum consecutive table-like pages, and predominance toward the document’s end. The output is a cutoff page index or None, indicating whether an annex should be removed.

# %%
# Detect annex cutoff point based on table-like patterns at the end of the document

def detect_annex_cutoff(
    table_flags: list[bool],
    min_consec=2,
    min_frac_rest=0.60,
    min_start_frac=0.50
):
    # Determine the page index where annex-like content begins
    n = len(table_flags)
    if n < 6:
        return None

    # Restrict cutoff search to the second half of the document
    start_min = int(n * min_start_frac)

    for i in range(start_min, n):
        if not table_flags[i]:
            continue

        # Count consecutive table-like pages starting at position i
        consec = 1
        j = i + 1
        while j < n and table_flags[j]:
            consec += 1
            j += 1

        # Validate minimum consecutive pages and overall table density
        if consec >= min_consec:
            rest = table_flags[i:]
            frac = sum(rest) / len(rest)
            if frac >= min_frac_rest:
                return i + 1  # Return 1-indexed page number

    return None

# %% [markdown]
# #### Truncated PDF Generation
#
# This block creates a cleaned version of the document when an annex cutoff has been detected. It generates a new PDF containing only the relevant pages (from the beginning up to the cutoff point), effectively removing the table-based annex at the end. This truncated document becomes the standardized input for subsequent OCR processing.

# %%
# Save truncated PDF up to the detected annex cutoff

def save_truncated_pdf(input_pdf: Path, output_pdf: Path, cutoff_page_1indexed: int):
    # Create a new PDF containing pages prior to the cutoff
    src = fitz.open(str(input_pdf))
    dst = fitz.open()

    last_keep = cutoff_page_1indexed - 1
    if last_keep < 1:
        src.close()
        dst.close()
        raise ValueError("Invalid cutoff: would remove entire document.")

    # Insert pages from the beginning up to the last page to retain
    dst.insert_pdf(src, from_page=0, to_page=last_keep - 1)

    # Ensure destination directory exists before saving
    output_pdf.parent.mkdir(parents=True, exist_ok=True)
    dst.save(str(output_pdf))

    dst.close()
    src.close()

# %% [markdown]
# #### Page-Level OCR Processing
#
# This block performs optical character recognition (OCR) on the cleaned PDF document, processing each page individually. Pages are rendered as images, minimally preprocessed to enhance legibility, and passed to Tesseract to extract text. The resulting page-level outputs are concatenated into a structured text representation for downstream analysis.

# %%
# Perform page-level OCR on the processed PDF

def ocr_pdf_to_text(pdf_path: Path, dpi: int, lang: str) -> str:
    # Extract text from each page using Tesseract OCR
    doc = fitz.open(str(pdf_path))
    parts = []

    for i in range(doc.page_count):
        page = doc.load_page(i)
        gray = render_page_gray(page, dpi=dpi)

        # Basic image preprocessing to enhance OCR accuracy
        gray = cv2.normalize(gray, None, 0, 255, cv2.NORM_MINMAX)
        bw = cv2.adaptiveThreshold(
            gray, 255,
            cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
            cv2.THRESH_BINARY,
            31, 11
        )

        # Tesseract configuration: LSTM engine with uniform text layout
        config = "--oem 3 --psm 6"
        txt = pytesseract.image_to_string(bw, lang=lang, config=config).strip()

        # Append page header for traceability
        parts.append(f"\n### Page {i+1}\n{txt}")

    doc.close()
    return "\n".join(parts).strip()

# %% [markdown]
# #### Single-Document Processing Pipeline
#
# This block orchestrates the complete processing workflow for a single PDF file. It detects potential annexes, generates a cleaned version of the document (if required), applies OCR to the resulting PDF, and produces both page-level text output and detailed metadata records. The block ensures structural consistency, reproducibility, and full traceability for each processed document.

# %%
# Process a single PDF end-to-end (annex detection, optional truncation, OCR, and per-file manifest)

from pathlib import Path
import json

def process_one_pdf(pdf_path: Path) -> dict:
    ts = datetime.utcnow().isoformat(timespec="seconds") + "Z"
    sha_in = sha256_file(pdf_path)

    # Derive year and relative input path from the raw directory structure
    rel_path = pdf_path.relative_to(RAW_ROOT)          # e.g., 2018/Document.pdf
    input_rel = rel_path.as_posix()                    # e.g., "2018/Document.pdf"
    year_dir = rel_path.parts[0]                       # e.g., "2018"
    base_name = pdf_path.stem                          # Filename without extension

    # Define per-year output layout
    out_year_dir = OUT_ROOT / year_dir
    out_pdf_dir = out_year_dir / "pdf"
    out_txt_dir = out_year_dir / "txt"
    out_json_dir = out_year_dir / "json"

    out_pdf_dir.mkdir(parents=True, exist_ok=True)
    out_txt_dir.mkdir(parents=True, exist_ok=True)
    out_json_dir.mkdir(parents=True, exist_ok=True)

    # Define output file paths (no per-document subdirectories)
    out_pdf_final = out_pdf_dir / f"{base_name}.pdf"
    out_txt = out_txt_dir / f"{base_name}.txt"
    out_manifest = out_json_dir / f"{base_name}.json"

    # Detect table-like pages to infer an annex cutoff near the document end
    table_flags, line_densities, n_pages = detect_table_like_pages(
        pdf_path, quick_dpi=QUICK_DPI, ld_threshold=LD_THRESHOLD
    )
    cutoff = detect_annex_cutoff(
        table_flags,
        min_consec=ANNEX_MIN_CONSEC,
        min_frac_rest=ANNEX_MIN_FRAC_REST,
        min_start_frac=ANNEX_MIN_START_FRAC
    )

    # Produce the final PDF (either copied as-is or truncated before annex pages)
    if cutoff is None:
        shutil.copy2(pdf_path, out_pdf_final)
        pages_kept = n_pages
        pages_removed = 0
        action_pdf = "copied_no_cut"
    else:
        save_truncated_pdf(pdf_path, out_pdf_final, cutoff_page_1indexed=cutoff)
        pages_kept = cutoff - 1
        pages_removed = n_pages - pages_kept
        action_pdf = "cut_annex_tables"

    # Run OCR on the final PDF and persist the extracted text
    text = ocr_pdf_to_text(out_pdf_final, dpi=OCR_DPI, lang=OCR_LANG)
    out_txt.write_text(text, encoding="utf-8", errors="ignore")

    sha_out = sha256_file(out_pdf_final)

    # Persist a per-document JSON manifest for traceability and diagnostics
    manifest = {
        "timestamp_utc": ts,
        "year": year_dir,
        "input_pdf": str(pdf_path),
        "input_rel": input_rel,
        "sha256_in": sha_in,
        "output_dir": str(out_year_dir),
        "output_pdf_final": str(out_pdf_final),
        "sha256_out": sha_out,
        "output_text": str(out_txt),
        "pages_total": n_pages,
        "cutoff_page_1indexed": cutoff,
        "pages_kept": pages_kept,
        "pages_removed": pages_removed,
        "action_pdf": action_pdf,
        "ocr": {"lang": OCR_LANG, "dpi": OCR_DPI},
        "table_detection": {
            "quick_dpi": QUICK_DPI,
            "ld_threshold": LD_THRESHOLD,
            "line_densities": line_densities,
            "table_flags": table_flags
        }
    }
    out_manifest.write_text(
        json.dumps(manifest, ensure_ascii=False, indent=2),
        encoding="utf-8"
    )

    # Return a single-row summary for the master manifest
    row = {
        "timestamp_utc": ts,
        "year": year_dir,
        "input_rel": input_rel,
        "input_pdf": str(pdf_path),
        "sha256_in": sha_in,
        "output_dir": str(out_year_dir),
        "output_pdf_final": str(out_pdf_final),
        "sha256_out": sha_out,
        "output_text": str(out_txt),
        "pages_total": n_pages,
        "cutoff_page_1indexed": cutoff,
        "pages_kept": pages_kept,
        "pages_removed": pages_removed,
        "action_pdf": action_pdf,
        "ocr_lang": OCR_LANG,
        "ocr_dpi": OCR_DPI,
        "status": "ok",
        "error": ""
    }
    return row

# %% [markdown]
# #### Batch Processing and Master Manifest Generation
#
# This block executes the full processing pipeline across all PDF files in the raw data directory. It iteratively applies the single-document workflow, handles errors without interrupting execution, and consolidates results into a master manifest file. The output ensures full corpus coverage, traceability, and structured documentation of all processing outcomes.

# %%
# Runner to process all PDFs under RAW_ROOT without skipping any files

def run_all_pdfs():
    pdfs = list_pdfs(RAW_ROOT)
    print("PDFs found:", len(pdfs))

    rows = []
    for i, pdf in enumerate(pdfs, 1):
        print(f"[{i}/{len(pdfs)}] Processing: {pdf.name}")
        try:
            row = process_one_pdf(pdf)
            rows.append(row)
        except Exception as e:
            # Record a minimal error row to keep full coverage in the master manifest
            rows.append({
                "timestamp_utc": datetime.utcnow().isoformat(timespec="seconds") + "Z",
                "year": find_year(pdf),
                "input_rel": str(pdf),
                "input_pdf": str(pdf),
                "sha256_in": "",
                "output_dir": "",
                "output_pdf_final": "",
                "sha256_out": "",
                "output_text": "",
                "pages_total": "",
                "cutoff_page_1indexed": "",
                "pages_kept": "",
                "pages_removed": "",
                "action_pdf": "",
                "ocr_lang": OCR_LANG,
                "ocr_dpi": OCR_DPI,
                "status": "error",
                "error": repr(e)
            })

    df = pd.DataFrame(rows)

    # Write the master manifest to disk
    MANIFEST_MASTER.parent.mkdir(parents=True, exist_ok=True)
    df.to_csv(MANIFEST_MASTER, index=False, encoding="utf-8")

    print("Master manifest written to:", MANIFEST_MASTER)
    print(df["status"].value_counts())
    return df

# %% [markdown]
# #### Execution and Sanity Check
#
# This block runs the batch pipeline and performs a quick verification by returning and previewing the consolidated manifest DataFrame. It serves as the notebook entry point for execution and basic output validation.

# %%
# Execute the full OCR pipeline and load the resulting master manifest into memory
df_manifest = run_all_pdfs()
# Display the first rows for verification
#df_manifest.head()
# Out:
# PDFs found: 329
# [1/329] Processing: 1-Proyecto-de-Decreto-de-Tamano-Empresarial-VF.pdf
# [2/329] Processing: DECRETO-10.pdf
# [3/329] Processing: DECRETO-11.pdf
# [4/329] Processing: DECRETO-12.pdf
# [5/329] Processing: DECRETO-13.pdf
# [6/329] Processing: DECRETO-14.pdf
# [7/329] Processing: DECRETO-15.pdf
# [8/329] Processing: DECRETO-16.pdf
# [9/329] Processing: DECRETO-17.pdf
# [10/329] Processing: DECRETO-19.pdf
# [11/329] Processing: DECRETO-2.pdf
# [12/329] Processing: DECRETO-20.pdf
# [13/329] Processing: DECRETO-21.pdf
# [14/329] Processing: DECRETO-22.pdf
# [15/329] Processing: DECRETO-23.pdf
# [16/329] Processing: DECRETO-24.pdf
# [17/329] Processing: DECRETO-25.pdf
# [18/329] Processing: DECRETO-26.pdf
# [19/329] Processing: DECRETO-27.pdf
# [20/329] Processing: DECRETO-28.pdf
# [21/329] Processing: DECRETO-29.pdf
# [22/329] Processing: DECRETO-3.pdf
# [23/329] Processing: DECRETO-30.pdf
# [24/329] Processing: DECRETO-31.pdf
# [25/329] Processing: DECRETO-32.pdf
# [26/329] Processing: DECRETO-5.pdf
# [27/329] Processing: DECRETO-6.pdf
# [28/329] Processing: DECRETO-7.pdf
# [29/329] Processing: DECRETO-8.pdf
# [30/329] Processing: DECRETO-9.pdf
# [31/329] Processing: DECRETO-NUMERO-DE-2018.pdf
# [32/329] Processing: image2019-02-25-104030.pdf
# [33/329] Processing: 16-9-2019-Proyecto-de-Decreto-NIIF-NIA-Consulta-publica.pdf
# [34/329] Processing: 190524-DGRESS-Proyecto-de-Decreto-Paso-a-UGPP.pdf
# [35/329] Processing: 1Pyto-Decreto-Prof-COL-ES-V3-Ajustada-OAJ-22-Jul-2019.pdf
# [36/329] Processing: 2019-05-28-Propuesta-decreto-composicion-JA-PTP.pdf
# [37/329] Processing: 2019-07-24-Decreto-Composicion-Opcion-3-1.pdf
# [38/329] Processing: 2019-09-04-Decreto-Patrimonios-Autonomos.pdf
# [39/329] Processing: 201900604Formato-proyecto-de-decreto.pdf
# [40/329] Processing: 2019jul27-Decreto-plazos-contribucion-turismo.pdf
# [41/329] Processing: Decreto-Ampliacion-TRH-28-06-2019.pdf
# [42/329] Processing: Decreto-Artesanias-de-Colombia-Delegado-de-MInistro.pdf
# [43/329] Processing: Decreto-de-implementacion-de-los-articulos-274-y-275-del-PND-Consolidado.pdf
# [44/329] Processing: Decreto-Guias-de-turismo.pdf
# [45/329] Processing: Decreto-Intervencion-Supersociedades.pdf
# [46/329] Processing: DECRETO-normas-obsoletas-DUR-1074-de-2015.pdf
# [47/329] Processing: DIC-26-19-PROYECTO-DE-DECRETO-COMPETENCIAS-LABORALES.pdf
# [48/329] Processing: P-D-Guias-de-Turismo-29-04-2019.pdf
# [49/329] Processing: PD-Art-39L1480-19072019.pdf
# [50/329] Processing: PD-CIRCULACION-FACTURA-ELECTRONICA-DE-VENTA-COMO-TITULO-VALOR-Consulta-publica.pdf
# [51/329] Processing: PD-Infraestructura.pdf
# [52/329] Processing: PD-Tarifas-Registro-mercantil-10oct19.pdf
# [53/329] Processing: PD-Tarifas-Registro-mercantil-1nov19.pdf
# [54/329] Processing: Por-el-cual-se-adiciona-el-Capitulo-13-y-la-Seccion-1-al-Decreto-1074-de-2015-reglamenta-el-paragrafo-2-del-articulo-3-de-la-Ley-1816-de.pdf
# [55/329] Processing: Por-el-cual-se-prorroga-la-vigencia-del-arancel-de-aduanas-para-determinadas-Subpartidas-del-Capitulo-64.pdf
# [56/329] Processing: PROYECTO-ANDJE.pdf
# [57/329] Processing: Proyecto-de-decreto-Astilleros.pdf
# [58/329] Processing: Proyecto-de-Decreto-Avaluadore.pdf
# [59/329] Processing: Proyecto-de-decreto-desdoblamientos.pdf
# [60/329] Processing: Proyecto-de-decreto-IMPUESTO-AL-TURISMO-22-09-2019.pdf
# [61/329] Processing: Proyecto-de-decreto-inclusion-de-unas-subpartidas-arancelarias-en-la-lista-de-bienes-de-capi.pdf
# [62/329] Processing: proyecto-de-decreto-medida-salvaguardia-barras-de-acero-ajustado-con-cambios-DIAN-enero-30-19-limpio.pdf
# [63/329] Processing: Proyecto-de-decreto-Parte-3-del-Libro-I-del-Decreto-Unico-Reglamen.pdf
# [64/329] Processing: Proyecto-de-decreto-Por-el-cual-se-derogan-unos-decretos.pdf
# [65/329] Processing: Proyecto-de-Decreto-Premio-Colombiano-a-la-Calidad-para-la-Exportacion.pdf
# [66/329] Processing: Proyecto-de-Decreto-Prorrogas-ZF-27-de-mayo-publicacion.pdf
# [67/329] Processing: Proyecto-de-Decreto-Sociedades-no-Operativas-V3.pdf
# [68/329] Processing: Proyecto-de-Decreto-UV523201944513-PM.pdf
# [69/329] Processing: Proyecto-de-decreto.pdf
# [70/329] Processing: Proyecto-Decreto-Aplicaicon-de-Derechos-Compensatorios-VF.pdf
# [71/329] Processing: Proyecto-decreto-BIC-v-13-06-2019-Post-abogacia.pdf
# [72/329] Processing: Proyecto-decreto-BIC-v-19-07-2019.pdf
# [73/329] Processing: Proyecto-decreto-BIC-v-23-09-2019-vF-REV.pdf
# [74/329] Processing: Proyecto-decreto-desgravacion-arancelaria-TLC-Col-ISRAEL-Sept-20-2019-P.pdf
# [75/329] Processing: PROYECTO-DECRETO-IMPO-TURISMO-VICE-DASYP-2-05-2019.pdf
# [76/329] Processing: Proyecto-decreto-megainversin-ajustado-ZF-V17062019.pdf
# [77/329] Processing: Proyecto-Decreto-Modificatorio-299-de-1995-Comentarios-JV-OJ.pdf
# [78/329] Processing: Proyecto-Decreto-PV-Sistemas-Especiales-de-Importacion-–-Exportaciones.pdf
# [79/329] Processing: Proyecto-Modificacion-Decreto-1595-de-2015.pdf
# [80/329] Processing: PROYECTO-PLAN-VALLEJO-INCORPORA-COMENTARIOS-DIAN-enero-17-19-LF.pdf
# [81/329] Processing: Proyecto-ProrrogaMaquinaria.pdf
# [82/329] Processing: Pyto-Dcto-ATI-Rev-040619.pdf
# [83/329] Processing: Pyto-de-decreto-chatarra-final-observaciones-OJ.pdf
# [84/329] Processing: Pyto-de-decreto-desdoblamientos-y-Colceramica.pdf
# [85/329] Processing: pyto-de-decreto-diferimiento-electrodomesticos-ajustado.pdf
# [86/329] Processing: Pyto-Decreto-Profundizacion-COL-GT-VDef.pdf
# [87/329] Processing: PytoD-ActualizacionD272.pdf
# [88/329] Processing: PytoD-Mod-D-1027.pdf
# [89/329] Processing: PytoDecretoVehiculos.pdf
# [90/329] Processing: VFF-Formato-proyecto-de-decreto-Insolvencia-22-11-2019.pdf
# [91/329] Processing: 02-07-20-PD-Desdoblamiento-Aguacates-y-Tapabocas.pdf
# [92/329] Processing: 04-08-20-PD-Reversion-de-Pagos.pdf
# [93/329] Processing: 06-08-20-PD-Reglamentario-del-772.pdf
# [94/329] Processing: 06-11-20-PD-Plazos-Justos.pdf
# [95/329] Processing: 09-06-20-PD-Prorroga-de-Contribucion-Parafiscal.pdf
# [96/329] Processing: 10-07-20-PD-Martillo-Electronico.pdf
# [97/329] Processing: 10-11-20-PD-Prorroga-Decreto-2279-de-2019-Aranceles-de-Calzado.pdf
# [98/329] Processing: 11-05-20-PD-Reversion-de-Pagos-VF.pdf
# [99/329] Processing: 11-11-20-PD-Motos-Electricas.pdf
# [100/329] Processing: 13-11-20-PD-Asbesto.pdf
# [101/329] Processing: 13-11-20-PD-ESTRUCTURA-SS.pdf
# [102/329] Processing: 13-11-20-PD-PLANTA-SS.pdf
# [103/329] Processing: 14-08-20-PD-Modificatorio-1910.pdf
# [104/329] Processing: 16-07-20-PD-Exclusion-de-Prohibicion-de-Exportacion-Decreto-462-de-2020.pdf
# [105/329] Processing: 16-12-2020-PD-Tarifas-VF.pdf
# [106/329] Processing: 17-11-20-PD-Captacion.pdf
# [107/329] Processing: 18-08-2020-PD-Depuracion-Normativa-DUR-CIT.pdf
# [108/329] Processing: 19-08-20-PD-Antidumping.pdf
# [109/329] Processing: 19-11-20-PD-ZFs.pdf
# [110/329] Processing: 20-11-20-Proyecto-de-decreto-sobre-importacion-de-vehiculos.pdf
# [111/329] Processing: 26-06-20-Decreto-Astilleros-27jun2020.pdf
# [112/329] Processing: 26-10-20-PD-Minamata.pdf
# [113/329] Processing: 28-10-20-PD-IVC-Empresas-Unipersonales-Salud.pdf
# [114/329] Processing: 29-07-20-PD-SEIEX.pdf
# [115/329] Processing: 30-07-2020-PD-NIIF-16.pdf
# [116/329] Processing: 31-07-20-Reforma-AIN-proyecto-de-decreto.pdf
# [117/329] Processing: 31-08-20-PD-Trazabilidad-de-Alcohol-Potable-y-no-Potable.pdf
# [118/329] Processing: Decreto-I-proyecto-importacion-exportacion-consumidor-turismo-y-zonas-francas.pdf
# [119/329] Processing: Decreto-II-proyecto-disposiciones-transitorias-comercio-turismo-zonas-francas.pdf
# [120/329] Processing: Decreto-por-el-cual-se-modifica-parcialmente-el-arancel-de-aduanas-Resina-PET.pdf
# [121/329] Processing: Decreto-por-el-cual-se-modifica-parcialmente-el-arancel-de-aduanas.pdf
# [122/329] Processing: P-D-Impuesto-al-Turismo-27-01-20.pdf
# [123/329] Processing: PD-ACICAM-y-FEDEGAN-06-02-20.pdf
# [124/329] Processing: PD-CCNeiva-REV-OAJ.pdf
# [125/329] Processing: PD-Chatarra-12-03-20-VF.pdf
# [126/329] Processing: PD-Desgravacion-Arancelaria-TLC-Israel-22-01-20.pdf
# [127/329] Processing: PD-Factura-Electronica-03-03-20.pdf
# [128/329] Processing: PD-Guias-de-Turismo-21-01-20FP.pdf
# [129/329] Processing: PD-Liquidacion-de-Sociedades-No-Operativas-05-02-20.pdf
# [130/329] Processing: PD-Por-el-cual-se-modifica-el-arancel-de-aduanas-publicacion.pdf
# [131/329] Processing: PD-Prohibicion-de-exportaciones-de-productos-Covid-19-01102020-V05-CP-MS.pdf
# [132/329] Processing: PD-Reglamentario-Insolvencia-DL560-29-04-30-VF.pdf
# [133/329] Processing: PD-Trigo-y-Sodio-12-03-20.pdf
# [134/329] Processing: Por-el-cual-se-modifica-parcialmente-el-arancel-de-aduanas-para-la-importacion-de-insumos-de-salud.pdf
# [135/329] Processing: Proy-Modif-Dec-2147-16-ZFs-18112020-ingles.pdf
# [136/329] Processing: Proyecto-de-decreto-exlcusion-de-contingente-para-la-chatarra-no-ferrosa.pdf
# [137/329] Processing: Proyecto-Decreto-creacion-de-cargos-permanetes-SIC-marzo-2020.pdf
# [138/329] Processing: Proyecto-Decreto-Deroga-D-1027-y-modif-D-272-07052020.pdf
# [139/329] Processing: Proyecto-Decreto-Exclusion-de-prohibicion-de-expo-de-varios-productos-V11-17062020.pdf
# [140/329] Processing: 01-06-21-PROYECTO-DECRETO-2021-considerandos-01062021-DCE-OALI-1-DIAN.pdf
# [141/329] Processing: 01-10-21-PD-Acero.pdf
# [142/329] Processing: 03-03-21-PD-PET.pdf
# [143/329] Processing: 05-10-21-PD-SIGR-VUCE.pdf
# [144/329] Processing: 06-12-21-PD-ONAC.pdf
# [145/329] Processing: 08-03-21-PD-NIIF-Enmiendas.pdf
# [146/329] Processing: 08-10-21-PD-Impuesto-Diferido-Limpio.pdf
# [147/329] Processing: 08-10-21-PD-Modificacion-Mercurio.pdf
# [148/329] Processing: 08-11-21-PD-VII-Enmienda.pdf
# [149/329] Processing: 10-03-21-PD-Confecciones.pdf
# [150/329] Processing: 10-08-21-PD-Normas-Corporativas-Vinculantes.pdf
# [151/329] Processing: 10-08-21-PD-Sandbox.pdf
# [152/329] Processing: 11-02-21-PD-Contribucion-Parafiscal-Turismo.pdf
# [153/329] Processing: 11-02-21-PD-Desdoblamiento-Vacunas.pdf
# [154/329] Processing: 12-04-21-PD-Consultorios-Empresariales.pdf
# [155/329] Processing: 12-04-21-PD-Pigmentos.pdf
# [156/329] Processing: 13-05-21-PD-Definiciones.pdf
# [157/329] Processing: 13-05-21-PD-MARTILLO-ELECTRONICO.pdf
# [158/329] Processing: 15-07-21-PD-Designacion-Presidente-del-CTCP-30jul2021.pdf
# [159/329] Processing: 15-09-21-PD-Atractivos-Puntos-Control-y-Carga-Limpio.pdf
# [160/329] Processing: 15-10-21-PD-Fiduciaria-FONTUR.pdf
# [161/329] Processing: 15-10-21-PD-SIFAI-VUI.pdf
# [162/329] Processing: 17-02-21-PD-Descuentos-Fiscales.pdf
# [163/329] Processing: 17-08-2021-PD-Guias-de-Turismo.pdf
# [164/329] Processing: 17-08-21-PD-Firma-Electronica-y-Digital.pdf
# [165/329] Processing: 17-09-21-PD-Modifica-HNM.pdf
# [166/329] Processing: 17-11-21-PD-Derechos-Compensatorios.pdf
# [167/329] Processing: 17-11-21-PD-Unificacion-de-Fuentes-de-Emprendimiento.pdf
# [168/329] Processing: 18-05-21-PD-Reglamentacion-Articulo-25-Ley-de-Emprendimiento.pdf
# [169/329] Processing: 18-08-21-PD-Contabilidad-Simplificada.pdf
# [170/329] Processing: 19-11-21-PD-Delacion.pdf
# [171/329] Processing: 21-01-21-PD-Gastronomia.pdf
# [172/329] Processing: 21-04-21-PD-Vehiculos-Hibridos.pdf
# [173/329] Processing: 22-01-21-PD-Asambleas-2021.pdf
# [174/329] Processing: 22-01-21-PD-Hipotesis-de-Negocio-en-Marcha.pdf
# [175/329] Processing: 22-04-21-PD-Chatarra-Ferrosa.pdf
# [176/329] Processing: 23-07-21-PD-Contingente-Automotor-23jul2021.pdf
# [177/329] Processing: 24-03-2021-PD-Adopcion-de-Politica-de-Sostenibilidad-Turistica.pdf
# [178/329] Processing: 24-06-2021-Borrador-PD-Apoyo-articulo-53-L2068-de-2020.pdf
# [179/329] Processing: 25-03-21-PD-CEmprende.pdf
# [180/329] Processing: 25-03-21-PD-Fondos-Territoriales.pdf
# [181/329] Processing: 26-01-21-PD-Bonos.pdf
# [182/329] Processing: 26-02-21-PD-Sello-de-Accesibilidad.pdf
# [183/329] Processing: 28-01-21-PD-Correccion-de-Errores-Ley-2069-de-2020.pdf
# [184/329] Processing: 28-09-21-PD-RNT.pdf
# [185/329] Processing: 29-03-21-PD-Red-Angeles-Empresarios-y-Voluntariado.pdf
# [186/329] Processing: 29-07-21-PD-Franquicias.pdf
# [187/329] Processing: 31-08-2021-PD-Empresas-de-Tiempo-Compartido.pdf
# [188/329] Processing: 31-08-2021-PD-Parques-Agroturismo-y-Ecoturismo.pdf
# [189/329] Processing: Proyecto-Decreto-Equipos-APNEA.pdf
# [190/329] Processing: Proyecto-Decreto-O2-y-concentradores.pdf
# [191/329] Processing: 01-06-2022-PD-Modificacion-Vigencia-Decreto-1880-IAMAS-SPC.pdf
# [192/329] Processing: 01-11-2022-PD-Arancel-advalorem-confecciones.pdf
# [193/329] Processing: 04-03-2022-PD-modificacion-arancel-productos-Insumos-Agropecuarios-MADR-02-03-2022.pdf
# [194/329] Processing: 04-05-2022-20220503-PD-NIIF-Modificaciones-y-enmiendas-vers-publicacion.pdf
# [195/329] Processing: 05-04-2022-PROYECTO-DECRETO-EXCLUSION-FLETES-Y-GASTOS-CONEXOS.pdf
# [196/329] Processing: 05-05-2022-Proyecto-Decreto-Trigo-30042022-rev-EF.pdf
# [197/329] Processing: 05-10-2022-PD-modificacion-Decreto-3303-de-2006.pdf
# [198/329] Processing: 07-06-2022-Proyecto-Decreto-desdoblamiento-barcos.pdf
# [199/329] Processing: 09-12-2022-PD-prorroga-arancel-calzado.pdf
# [200/329] Processing: 1-02-2022-PD-prorroga-plan-vallejo-expres.pdf
# [201/329] Processing: 10-12-2022-PD-medidas-hurto-celulares.pdf
# [202/329] Processing: 11-02-2022-PD-teletrabajo-ZF.pdf
# [203/329] Processing: 12-09-22-PD-Normas-de-Aseguramiento.pdf
# [204/329] Processing: 14-02-2022-Proyecto-Decreto-Sello-Creo-en-Ti.pdf
# [205/329] Processing: 17-02-2022-PD-modificacion-arancel-productos-canasta-basica-e-insumos.pdf
# [206/329] Processing: 17-11-2022-Proyecto-Decreto-Contingente-Chatarra-2022.pdf
# [207/329] Processing: 18-02-2022-Proyecto-Decreto-Implementacion-tlc-Col-UK.pdf
# [208/329] Processing: 20220330-PD-modificacion-Decreto-419-de-2021.pdf
# [209/329] Processing: 21-06-2022-Proyecto-de-Decreto-gobierno-corporativo-camaras.pdf
# [210/329] Processing: 21-11-2022-PD-Delegacion-IV-ESAL-dom-extranjero.pdf
# [211/329] Processing: 22-03-2022-PD-modificacion-requisitos-de-procedencia-fondos-territoriales.pdf
# [212/329] Processing: 22-06-2022-Proyecto-Dcto-reduccion-arancel-fertilizantes-Decto-894.pdf
# [213/329] Processing: 22-06-2022-Proyecto-Dcto-reduccion-arancel-mani-Decreto-882-de-2020.pdf
# [214/329] Processing: 22-11-2022-Proyecto-Decreto-modifica-272.pdf
# [215/329] Processing: 22-12-2022-PD-impuesto-diferido-renta-gan-ocasi-sin-CC.pdf
# [216/329] Processing: 23-05-2022-PROYECTO-DECRETO-EXCLUSION-FLETES-Y-GASTOS-CONEXOS-sesion356.pdf
# [217/329] Processing: 23-05-2022-Proyecto-lista-de-bienes-de-capital.pdf
# [218/329] Processing: 25-01-22-PD-modificacion-decreto-1644-de-2021.pdf
# [219/329] Processing: 27-01-2022-PD-correccion-yerro-dec-1845.pdf
# [220/329] Processing: 03-04-2023-PD-Insumos-Agropecuarios-2023.pdf
# [221/329] Processing: 05-05-2023-PD-modifica-Decreto-1074-2015-Auxiliares-de-la-Justicia-VF.pdf
# [222/329] Processing: 07-12-2023-PD-Vehiculos-Hibridos.pdf
# [223/329] Processing: 08-06-2023-PD-IAMAS.pdf
# [224/329] Processing: 10-01-2023-PD-modifica-el-Decreto-1100-de-2020.pdf
# [225/329] Processing: 10-05-2023-PD-modificacion-decreto-1074-subsidios-a-prestadores-turisticos.pdf
# [226/329] Processing: 11-10-2023-PD-Creacion-Camara-de-Comercio-Soacha.pdf
# [227/329] Processing: 17-10-2023-PD-DEBERES-ADMINISTRADORES-CONFLICTO-DE-INTERESES.pdf
# [228/329] Processing: 18-12-2023-PD-modifica-paragrafo-del-articulo-2-2-3-8-3-2-del-Decreto-1074-de-2015-SIED.pdf
# [229/329] Processing: 19-10-2023-PD-Arancel-Alambres-Sesion-365.pdf
# [230/329] Processing: 19-10-2023-PD-Restablecimiento-Arancel-Decreto-272-de-2018-Sesion-365.pdf
# [231/329] Processing: 19-10-2023-PD-zonas-francas-mixtas.pdf
# [232/329] Processing: 20-09-2023-PD-apnea-oxigeno-y-mani.pdf
# [233/329] Processing: 20-11-2023-PD-reglamenta-RTPP-de-Colombia.pdf
# [234/329] Processing: 24-04-2023-PD-reglamento-Ley-915-San-Andres.pdf
# [235/329] Processing: 24-10-2023-PD-Beneficios-por-colaboracion.pdf
# [236/329] Processing: 25-01-2023-PD-Modificacion-del-arancel-de-aduanas-desdoblamiento.pdf
# [237/329] Processing: 25-04-2023-PD-Vehiculos-Hibridos-sesion-363.pdf
# [238/329] Processing: 25-08-2023-PD-Funcionamiento-del-Consejo-Nacional-de-la-Economia-Popular.pdf
# [239/329] Processing: 25-08-2023-PD-Organizacion-y-funcionamiento-del-Sistema-Nacional-de-Competitividad-e-Innovacion-SNCI.pdf
# [240/329] Processing: 25-08-2023-PD-PROFIA.pdf
# [241/329] Processing: 26-04-2023-PD-Contingente-arancelario-IAMAS.pdf
# [242/329] Processing: 27-10-2023-PD-modificacion-arancel-de-aduanas-decision-906-CAN.pdf
# [243/329] Processing: 27-11-2023-PD-modificiacion-Decreto-2025-de-2015.pdf
# [244/329] Processing: 28-04-2023-PD-modificacion-entrega-Premio-Innova.pdf
# [245/329] Processing: 28-06-2023-PD-planeacion-y-descentralizacion-del-turismo.pdf
# [246/329] Processing: 29-05-2023-PD-NIA-701.pdf
# [247/329] Processing: 29-08-2023-PD-Incorporacion-NIIF-17-contrato-de-Seguro.pdf
# [248/329] Processing: 30-10-2023-PD-Nuevo-modelo-tarifario-registro-mercantil.pdf
# [249/329] Processing: 31-05-2023-PD-Plan-internacionalizacion-zonas-francas.pdf
# [250/329] Processing: 31-10-2023-PD-modifica-Comite-de-practicas-comerciales.pdf
# [251/329] Processing: 31-10-2023-PD-Por-el-cual-se-modifica-parcialmente-el-Decreto-3303-de-2006.pdf
# [252/329] Processing: 01-03-2024-PD-Desdoblamiento-hierbas-aromaticas-SPC-CC.pdf
# [253/329] Processing: 02-02-2024-PD-Programa-de-Fomento-para-la-Industria-Automotriz-y-se-deroga-el-Decreto-1122-de-2019.pdf
# [254/329] Processing: 02-10-2024-PD-Arancel-de-Aduanas-para-las-importaciones-de-lentes-de-otras-materias-para-gafas.pdf
# [255/329] Processing: 05-06-2024-PD-Modificacion-Decreto-1074-de-2015.pdf
# [256/329] Processing: 05-08-2024-PD-se-reglamenta-parcialmente-la-Ley-2184-de-2022.pdf
# [257/329] Processing: 05-12-2024-PD-Decreto-272-del-13-de-febrero-de-2018-y-el-Arancel-de-Aduanas.pdf
# [258/329] Processing: 06-08-2024-PD-se-modifica-el-Decreto-1074-de-2015.pdf
# [259/329] Processing: 07-06-2024-PD-Restriccion-exportacion-carbon-a-Israel.pdf
# [260/329] Processing: 10-05-2024-PD-Certificado-de-Reembolso-Tributario-CERT.pdf
# [261/329] Processing: 12-08-2024-PD-modifican-los-umbrales-establecidos-en-el-Decreto-2218-de-2017.pdf
# [262/329] Processing: 12-08-2024-PD-reglamentan-las-compensaciones-industriales-en-el-marco-de-la-Politica-de-Reindustrializacion.pdf
# [263/329] Processing: 16-04-2024-PD-IAMAS-autopartes.pdf
# [264/329] Processing: 17-12-2024-PD-medidas-para-la-prevencion-y-el-control-del-fraude-aduanero-en-las-importaciones-de-hilos-de-coser-de-fibras-sinteticas.pdf
# [265/329] Processing: 18-06-2024-PD-diferimiento-arancelario-trigo.pdf
# [266/329] Processing: 18-10-2024-PD-personas-juridicas-sujetas-a-la-vigilancia-de-la-Superintendencia-de-Sociedades.pdf
# [267/329] Processing: 20-02-2024-PD-integracion-y-operacion-de-los-patrimonios-autonomos-iNNpulsa-Colombia-y-Colombia-Productiva.pdf
# [268/329] Processing: 20-03-2024-PD-TLC-Colombia-y-Costa-Rica.pdf
# [269/329] Processing: 22-07-2024-PD-corrige-un-error-formal-en-el-Decreto-2266-de-2023.pdf
# [270/329] Processing: 22-07-2024-PD-derechos-por-registro-y-renovacion-de-la-matricula-mercantil.pdf
# [271/329] Processing: 22-07-2024-PD-Red-Colombiana-de-Metrologia.pdf
# [272/329] Processing: 23-08-2024-PD-se-corrige-un-error-formal-en-el-Decreto-2266-de-2023.pdf
# [273/329] Processing: 24-09-2024-PD-PROFIA.pdf
# [274/329] Processing: 25-04-2024-PD-compensaciones-industriales-en-el-marco-de-la-Politica-de-Reindustrializacion.pdf
# [275/329] Processing: 25-04-2024-PD-incorpora-la-Norma-de-Informacion-Financiera-NIIF-17.pdf
# [276/329] Processing: 25-10-2024-PD-deroga-el-Decreto-1116-de-2017.pdf
# [277/329] Processing: 25-11-2024-PD-Arancel-de-Aduanas-para-la-importacion-de-insumos-agropecuarios.pdf
# [278/329] Processing: 26-12-2024-PD-modifica-parcialmente-el-Arancel-de-Aduanas-para-el-sector-automotor.pdf
# [279/329] Processing: 26-12-2024-PD-reglamenta-el-Certificado-de-Reembolso-Tributario-CERT.pdf
# [280/329] Processing: 27-02-2024-PD-Decreto-2266-de-2023-2.pdf
# [281/329] Processing: 28-11-2024-PD-reglamenta-el-articulo-86-de-la-Ley-2294-de-2023.pdf
# [282/329] Processing: 30-05-2024-PD-Insumos-agropecuarios-SPC-CC.pdf
# [283/329] Processing: 30-07-2024-PD-reglamenta-el-articulo-86-de-la-Ley-2294-de-2023.pdf
# [284/329] Processing: 31-05-2024-PD-modifican-los-articulos-1-y-3-del-Decreto-3990-de-2010.pdf
# [285/329] Processing: 31-12-2024-PD-condiciones-y-requisitos-para-la-declaratoria-de-existencia-de-zonas-francas-permanentes-especiales.pdf
# [286/329] Processing: 31-12-2024-PD-participacion-camaras-de-comercio-programas-reindustrializacion-turismo-y-comercio-exterior.pdf
# [287/329] Processing: 01-06-2025-PD-Reglamenta-art-98-PND-11-04-2025.pdf
# [288/329] Processing: 02-07-2025-PD-ENMIENDAS-NIIF-y-NIIF-PYMES.pdf
# [289/329] Processing: 02-12-2025-PD-Registro-Nacional-de-Turismo-RNT.pdf
# [290/329] Processing: 03-12-2025-PD-umbrales-arancel-aduanas.pdf
# [291/329] Processing: 04-06-2025-PD-reglamenta-el-articulo-86-de-la-Ley-2294-de-2023.pdf
# [292/329] Processing: 04-07-2025-PD-reglamentacion-condiciones-y-requisitos-declaratoria-existencia-zonas-francas-permanentes-especiales-ferreas.pdf
# [293/329] Processing: 05-12-2025-PD-incremento-arancel-importaciones-sector-siderurgico-y-metalmecanico.pdf
# [294/329] Processing: 06-05-2025-PD-modifica-el-Decreto-2147-de-2016-zonas-francas.pdf
# [295/329] Processing: 07-11-2025-PD-modifica-Arancel-Aduanas-Nacionales-importaciones-vehiculos-y-motos-gasolina-o-diesel.pdf
# [296/329] Processing: 08-08-2025-PD-control-del-fraude-aduanero-en-las-importaciones-de-hilos-de-coser.pdf
# [297/329] Processing: 08-08-2025-PD-deroga-Premio-Colombiano-a-la-Innovacion-Empresarial-para-las-MiPymes.pdf
# [298/329] Processing: 08-08-2025-PD-Inclusion-de-Subpartida-como-Bien-de-Capital-SPC-CACN.pdf
# [299/329] Processing: 09-09-2025-PD-aranceles-para-insumos-y-materias-primas-de-confecciones.pdf
# [300/329] Processing: 10-02-2025-PD-TLC-Colombia-y-Chile.pdf
# [301/329] Processing: 10-10-2025-PD-nombramiento-y-remocion-SIC-SF-y-SS.pdf
# [302/329] Processing: 10-11-2025-PD-Modificacion-IAMAS.pdf
# [303/329] Processing: 10-12-2025-PD-modifica-Decreto-1881-de-2021-y-se-incrementa-arancel-importaciones-baldosas-ceramicas.pdf
# [304/329] Processing: 12-06-2025-PD-entrada-en-operacion-del-nuevo-patrimonio-autonomo-iNNpulsa-Colombia.pdf
# [305/329] Processing: 12-11-2025-PD-incremento-aranceles-siderurgico.pdf
# [306/329] Processing: 12-11-2025-PD-zonas-francas-permanentes-especiales-actividades-ferroviarias.pdf
# [307/329] Processing: 15-09-2025-PD-aranceles-para-insumos-de-confecciones.pdf
# [308/329] Processing: 15-09-2025-PD-modifica-arancel-aduanas-bieletas-estabilizadoras-de-suspension-de-vehiculos.pdf
# [309/329] Processing: 18-06-2025-PD-contingente-para-las-exportaciones-de-desperdicios-y-desechos-de-chatarra.pdf
# [310/329] Processing: 19-09-2025-PD-composicion-del-Comite-Directivo-del-Fondo-Nacional-de-Turismo.pdf
# [311/329] Processing: 21-07-2025-PD-Arancel-Aduanas-importaciones-insumos-sector-confecciones-y-calzado.pdf
# [312/329] Processing: 21-07-2025-PD-compensaciones-industriales-en-el-marco-de-la-Politica-de-Reindustrializacion.pdf
# [313/329] Processing: 21-07-2025-PD-modifica-Arancel-Aduanas-importaciones-buses-electricos.pdf
# [314/329] Processing: 21-07-2025-PD-modifica-Decreto-2147-de-2016-Zonas-Francas-y-Economia-Popular.pdf
# [315/329] Processing: 21-07-2025-PD-modifica-parcialmente-Decreto-566-de-2025-CERT.pdf
# [316/329] Processing: 21-08-2025-PD-Plan-Nacional-de-Desarrollo-2022-–-2026-compensaciones-industriales.pdf
# [317/329] Processing: 21-10-2025-PD-Desdoblamiento-arancelario-CANNABIS-3A.pdf
# [318/329] Processing: 21-11-2025-PD-Acuerdo-sobre-Tecnologia-de-la-Informacion-ATI-de-la-OMC.pdf
# [319/329] Processing: 21-11-2025-PD-modifica-en-lo-relativo-a-las-buenas-practicas-de-reglamentacion-tecnica.pdf
# [320/329] Processing: 23-09-2025-PD-Reversion-de-Pagos.pdf
# [321/329] Processing: 24-01-2025-PD-Camara-de-comercio-de-Soacha-MODIF-22102023.pdf
# [322/329] Processing: 26-11-2025-PD-restablecimiento-arancel-Decreto-272-del-13-de-febrero-de-2018.pdf
# [323/329] Processing: 27-05-2025-PD-reglamenta-el-Decreto-Ley-1094-de-2024-CRIC.pdf
# [324/329] Processing: 27-07-2025-PD-prohibicion-a-las-exportaciones-de-carbon-a-Israel.pdf
# [325/329] Processing: 28-02-2025-PD-encargada-de-la-administracion-del-patrimonio-autonomo-INNpulsa.pdf
# [326/329] Processing: 29-04-2025-PD-adiciona-un-paragrafo-al-articulo-70-del-Decreto-2147-de-2016.pdf
# [327/329] Processing: 29-10-2025-PD-medidas-prevencion-y-control-fraude-aduanero-en-importaciones-arroces-semiblanqueados-o-blanqueados.pdf
# [328/329] Processing: 31-07-2025-PD-modifica-Arancel-de-Aduanas-importacion-insumos-agropecuarios.pdf
# [329/329] Processing: Proyecto-Decreto-Aranceles-Sector-Automotor.pdf
# Master manifest written to: C:\Users\dtruj\Documentos\proyectos\legal-uncertainty-index\data_processed\mincit\pdf_ocr\manifests\manifest_ocr.csv
# status
# ok    329
# Name: count, dtype: int64

# %% [markdown]
# ### Post-Processing Review and Validation of OCR Outputs

# %%
# Load the master OCR manifest from disk for inspection or post-processing
import pandas as pd

df = pd.read_csv("manifest_ocr.csv", sep=";")

# Preview the first rows if needed
# print(df.head())

# %%
# Count non-null error entries in the master manifest
num_errors = df["error"].notna().sum()
print("Number of errors:", num_errors)
# Out:
# Number of errors: 0

# %%
# Compute frequency distribution of processing status values

status_counts = df["status"].value_counts(dropna=False)
print(status_counts)
# Out:
# status
# ok    329
# Name: count, dtype: int64

# %%
# Compute frequency distribution of PDF processing actions

action_counts = df["action_pdf"].value_counts(dropna=False)
print(action_counts)
# Out:
# action_pdf
# copied_no_cut       310
# cut_annex_tables     19
# Name: count, dtype: int64

# %%
# Identify documents where annex tables were removed

cut_annex_tables = (
    df.loc[df["action_pdf"] == "cut_annex_tables", ["input_rel", "action_pdf"]]
    .sort_values(by="input_rel")
    .reset_index(drop=True)
)

print(cut_annex_tables.to_string(index=False))
# Out:
#                                                                                   input_rel       action_pdf
#                                                                          2018/DECRETO-2.pdf cut_annex_tables
#            2019/Proyecto-decreto-desgravacion-arancelaria-TLC-Col-ISRAEL-Sept-20-2019-P.pdf cut_annex_tables
#                                                           2019/Pyto-Dcto-ATI-Rev-040619.pdf cut_annex_tables
#                                            2019/Pyto-Decreto-Profundizacion-COL-GT-VDef.pdf cut_annex_tables
#                                                            2019/PytoD-ActualizacionD272.pdf cut_annex_tables
#                                                                    2020/19-11-20-PD-ZFs.pdf cut_annex_tables
#                                    2020/PD-Desgravacion-Arancelaria-TLC-Israel-22-01-20.pdf cut_annex_tables
#                                         2020/Proy-Modif-Dec-2147-16-ZFs-18112020-ingles.pdf cut_annex_tables
#                                                    2021/17-02-21-PD-Descuentos-Fiscales.pdf cut_annex_tables
#                              2022/18-02-2022-Proyecto-Decreto-Implementacion-tlc-Col-UK.pdf cut_annex_tables
#                                     2022/23-05-2022-Proyecto-lista-de-bienes-de-capital.pdf cut_annex_tables
#                             2023/29-08-2023-PD-Incorporacion-NIIF-17-contrato-de-Seguro.pdf cut_annex_tables
#                             2024/10-05-2024-PD-Certificado-de-Reembolso-Tributario-CERT.pdf cut_annex_tables
#                                            2024/20-03-2024-PD-TLC-Colombia-y-Costa-Rica.pdf cut_annex_tables
#                 2024/25-04-2024-PD-incorpora-la-Norma-de-Informacion-Financiera-NIIF-17.pdf cut_annex_tables
# 2024/26-12-2024-PD-modifica-parcialmente-el-Arancel-de-Aduanas-para-el-sector-automotor.pdf cut_annex_tables
#               2024/26-12-2024-PD-reglamenta-el-Certificado-de-Reembolso-Tributario-CERT.pdf cut_annex_tables
#               2024/31-05-2024-PD-modifican-los-articulos-1-y-3-del-Decreto-3990-de-2010.pdf cut_annex_tables
#                                        2025/Proyecto-Decreto-Aranceles-Sector-Automotor.pdf cut_annex_tables

# %%
# Compute the number of documents with and without removed pages

no_pages_removed_count = (df["pages_removed"] == 0).sum()
pages_removed_count = (df["pages_removed"] > 0).sum()

print("Observations without pages_removed:", no_pages_removed_count)
print("Observations with pages_removed:", pages_removed_count)
# Out:
# Observations without pages_removed: 310
# Observations with pages_removed: 19

# %%
# Identify documents with one or more pages removed during processing

removed_pages_table = (
    df.loc[df["pages_removed"] > 0, ["input_rel", "pages_removed"]]
    .sort_values(by="pages_removed", ascending=False)
    .reset_index(drop=True)
)

print(removed_pages_table.to_string(index=False))
# Out:
#                                                                                   input_rel  pages_removed
#                              2022/18-02-2022-Proyecto-Decreto-Implementacion-tlc-Col-UK.pdf             38
#                                    2020/PD-Desgravacion-Arancelaria-TLC-Israel-22-01-20.pdf             23
#            2019/Proyecto-decreto-desgravacion-arancelaria-TLC-Col-ISRAEL-Sept-20-2019-P.pdf             18
#                             2024/10-05-2024-PD-Certificado-de-Reembolso-Tributario-CERT.pdf             16
#               2024/26-12-2024-PD-reglamenta-el-Certificado-de-Reembolso-Tributario-CERT.pdf             15
#                                         2020/Proy-Modif-Dec-2147-16-ZFs-18112020-ingles.pdf             14
#                                                                    2020/19-11-20-PD-ZFs.pdf             11
#                                            2019/Pyto-Decreto-Profundizacion-COL-GT-VDef.pdf              8
#                                                                          2018/DECRETO-2.pdf              8
#                                                           2019/Pyto-Dcto-ATI-Rev-040619.pdf              7
#                                                            2019/PytoD-ActualizacionD272.pdf              7
#                                            2024/20-03-2024-PD-TLC-Colombia-y-Costa-Rica.pdf              6
#                                                    2021/17-02-21-PD-Descuentos-Fiscales.pdf              5
#                                     2022/23-05-2022-Proyecto-lista-de-bienes-de-capital.pdf              3
#                             2023/29-08-2023-PD-Incorporacion-NIIF-17-contrato-de-Seguro.pdf              3
#                 2024/25-04-2024-PD-incorpora-la-Norma-de-Informacion-Financiera-NIIF-17.pdf              3
# 2024/26-12-2024-PD-modifica-parcialmente-el-Arancel-de-Aduanas-para-el-sector-automotor.pdf              3
#               2024/31-05-2024-PD-modifican-los-articulos-1-y-3-del-Decreto-3990-de-2010.pdf              3
#                                        2025/Proyecto-Decreto-Aranceles-Sector-Automotor.pdf              3

# %%
#Comparison between table1 & table2
import pandas as pd

# --- Build name sets from the two tables ---
names_cut = set(cut_annex_tables["input_rel"].dropna().astype(str).str.strip())
names_removed = set(removed_pages_table["input_rel"].dropna().astype(str).str.strip())

# --- Quick equality check ---
are_identical = (names_cut == names_removed)
print("Are the document names identical?:", are_identical)
print("Count (cut_annex_tables):", len(names_cut))
print("Count (pages_removed > 0):", len(names_removed))
print("Intersection:", len(names_cut & names_removed))

# --- Detailed comparison table ---
comparison = (
    pd.DataFrame({"input_rel": sorted(names_cut | names_removed)})
    .assign(
        in_cut=lambda d: d["input_rel"].isin(names_cut),
        in_removed=lambda d: d["input_rel"].isin(names_removed),
    )
    .assign(
        match=lambda d: d["in_cut"] & d["in_removed"]
    )
    .sort_values(["match", "input_rel"], ascending=[True, True])
    .reset_index(drop=True)
)

print(comparison.to_string(index=False))

# --- Differences (optional, but useful) ---
only_in_cut = sorted(names_cut - names_removed)
only_in_removed = sorted(names_removed - names_cut)

print("\nOnly in cut_annex_tables:", len(only_in_cut))
print("\n".join(only_in_cut[:50]) if only_in_cut else "None")

print("\nOnly in removed_pages_table:", len(only_in_removed))
print("\n".join(only_in_removed[:50]) if only_in_removed else "None")
# Out:
# Are the document names identical?: True
# Count (cut_annex_tables): 19
# Count (pages_removed > 0): 19
# Intersection: 19
#                                                                                   input_rel  in_cut  in_removed  match
#                                                                          2018/DECRETO-2.pdf    True        True   True
#            2019/Proyecto-decreto-desgravacion-arancelaria-TLC-Col-ISRAEL-Sept-20-2019-P.pdf    True        True   True
#                                                           2019/Pyto-Dcto-ATI-Rev-040619.pdf    True        True   True
#                                            2019/Pyto-Decreto-Profundizacion-COL-GT-VDef.pdf    True        True   True
#                                                            2019/PytoD-ActualizacionD272.pdf    True        True   True
#                                                                    2020/19-11-20-PD-ZFs.pdf    True        True   True
#                                    2020/PD-Desgravacion-Arancelaria-TLC-Israel-22-01-20.pdf    True        True   True
#                                         2020/Proy-Modif-Dec-2147-16-ZFs-18112020-ingles.pdf    True        True   True
#                                                    2021/17-02-21-PD-Descuentos-Fiscales.pdf    True        True   True
#                              2022/18-02-2022-Proyecto-Decreto-Implementacion-tlc-Col-UK.pdf    True        True   True
#                                     2022/23-05-2022-Proyecto-lista-de-bienes-de-capital.pdf    True        True   True
#                             2023/29-08-2023-PD-Incorporacion-NIIF-17-contrato-de-Seguro.pdf    True        True   True
#                             2024/10-05-2024-PD-Certificado-de-Reembolso-Tributario-CERT.pdf    True        True   True
#                                            2024/20-03-2024-PD-TLC-Colombia-y-Costa-Rica.pdf    True        True   True
#                 2024/25-04-2024-PD-incorpora-la-Norma-de-Informacion-Financiera-NIIF-17.pdf    True        True   True
# 2024/26-12-2024-PD-modifica-parcialmente-el-Arancel-de-Aduanas-para-el-sector-automotor.pdf    True        True   True
#               2024/26-12-2024-PD-reglamenta-el-Certificado-de-Reembolso-Tributario-CERT.pdf    True        True   True
#               2024/31-05-2024-PD-modifican-los-articulos-1-y-3-del-Decreto-3990-de-2010.pdf    True        True   True
#                                        2025/Proyecto-Decreto-Aranceles-Sector-Automotor.pdf    True        True   True
#
# Only in cut_annex_tables: 0
# None
#
# Only in removed_pages_table: 0
# None

# %%
# Inspect top documents with annex truncation by number of removed pages

df.loc[df["action_pdf"] == "cut_annex_tables",
       ["input_rel", "pages_total", "pages_removed", "cutoff_page_1indexed"]
      ] \
  .sort_values("pages_removed", ascending=False) \
  .head(10)
# Out:
#                                              input_rel  pages_total  \
# 206  2022/18-02-2022-Proyecto-Decreto-Implementacio...           76
# 125  2020/PD-Desgravacion-Arancelaria-TLC-Israel-22...           45
# 73   2019/Proyecto-decreto-desgravacion-arancelaria...           35
# 259  2024/10-05-2024-PD-Certificado-de-Reembolso-Tr...           31
# 278  2024/26-12-2024-PD-reglamenta-el-Certificado-d...           30
# 134  2020/Proy-Modif-Dec-2147-16-ZFs-18112020-ingle...           43
# 108                           2020/19-11-20-PD-ZFs.pdf           44
# 85    2019/Pyto-Decreto-Profundizacion-COL-GT-VDef.pdf           15
# 10                                  2018/DECRETO-2.pdf           15
# 81                   2019/Pyto-Dcto-ATI-Rev-040619.pdf           14
#
#      pages_removed  cutoff_page_1indexed
# 206             38                  39.0
# 125             23                  23.0
# 73              18                  18.0
# 259             16                  16.0
# 278             15                  16.0
# 134             14                  30.0
# 108             11                  34.0
# 85               8                   8.0
# 10               8                   8.0
# 81               7                   8.0

# %%
# Compute descriptive statistics for documents with annex truncation

df_cut = df[df["action_pdf"] == "cut_annex_tables"].copy()
# Calculate the proportion of pages removed per document
df_cut["pct_removed"] = df_cut["pages_removed"] / df_cut["pages_total"]
# Generate summary statistics for removed pages and removal ratio
summary = df_cut[["pages_removed", "pct_removed"]].describe()
summary
# Out:
#        pages_removed  pct_removed
# count      19.000000    19.000000
# mean       10.210526     0.466204
# std         8.991224     0.095799
# min         3.000000     0.250000
# 25%         3.000000     0.464286
# 50%         7.000000     0.500000
# 75%        14.500000     0.524731
# max        38.000000     0.555556

# %%
# Rank documents with annex truncation by proportion of pages removed

df_cut[["pages_total", "pages_removed", "pct_removed"]] \
    .sort_values("pct_removed", ascending=False) \
    .head(10)
# Out:
#      pages_total  pages_removed  pct_removed
# 161            9              5     0.555556
# 267           11              6     0.545455
# 86            13              7     0.538462
# 10            15              8     0.533333
# 85            15              8     0.533333
# 259           31             16     0.516129
# 73            35             18     0.514286
# 125           45             23     0.511111
# 81            14              7     0.500000
# 216            6              3     0.500000

# %%
# Compute mean and standard deviation of the proportion of pages removed

df_cut["pct_removed"].mean(), df_cut["pct_removed"].std()
# Out:
# (np.float64(0.4662040838828457), np.float64(0.09579932079026335))
