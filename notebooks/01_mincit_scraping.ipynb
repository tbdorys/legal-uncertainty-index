# %%
import os

# Move working directory to project root
os.chdir("..")

PROJECT_ROOT = os.getcwd()
print("Project root:", PROJECT_ROOT)
# Out:
# Project root: C:\Users\dtruj\Documentos\proyectos

# %% [markdown]
# **Author:** Dorys Trujillo
# **Project:** Legal Uncertainty Index (IIJ)
# **Data Source:** Ministry of Commerce, Industry and Tourism (MinCIT)
# **Period:** 2018–2025

# %% [markdown]
# ## Automated Web Scraping of MinCIT Regulatory Drafts (2018–2025)
#
# This notebook implements an automated pipeline to collect draft decree documents published by the Colombian Ministry of Commerce, Industry and Tourism (MinCIT) between 2018 and 2025. The extracted corpus serves as the primary data source for constructing the Legal Uncertainty Index (IIJ) and represents the data ingestion layer of the project.
#
# The workflow includes automated navigation, link extraction, file downloads, and structured local storage.

# %% [markdown]
# ### Environment Setup and Dependencies
#
# This step installs the required dependencies for the scraping pipeline, including Playwright (browser automation), Requests (HTTP downloads), nest_asyncio (Jupyter event loop support), and the Chromium browser engine.
#
# ⚠️ These commands only need to be executed once per environment.

# %%
# One-time environment setup (run only once per environment)

# Install required Python packages
# pip install playwright requests nest_asyncio

# Install Playwright browser dependencies
# playwright install chromium

# %% [markdown]
# ### Library Imports and Core Dependencies
#
# This section loads all core libraries required for the scraping pipeline, covering file system operations, asynchronous execution, HTTP communication, URL processing, Playwright-based browser automation, and tabular data management with pandas.

# %%
# System and file management
import os
import shutil

# Time and asynchronous execution
import time
import asyncio

# Text processing and pattern matching
import re

# HTTP requests and file downloads
import requests

# URL utilities for decoding and link reconstruction
from urllib.parse import unquote, urljoin

# Browser automation for dynamic web scraping
from playwright.async_api import async_playwright

# Data handling and tabular storage
import pandas as pd

# %% [markdown]
# ### Windows Compatibility Fix
#
# This section applies a Windows-specific event loop policy required to prevent Playwright and AsyncIO conflicts in Jupyter environments. Deprecation warnings are also suppressed to keep execution output clean. The configuration only affects Windows systems.

# %%
# Windows compatibility fix for Playwright

import warnings
import sys
# Suppress deprecation warnings to reduce console noise
warnings.filterwarnings("ignore", category=DeprecationWarning)

# Apply Windows-specific event loop policy required by Playwright
if sys.platform.startswith("win"):
    asyncio.set_event_loop_policy(asyncio.WindowsSelectorEventLoopPolicy())

# %% [markdown]
# ### Async Execution Helper (Jupyter + Playwright)
#
# This helper enables safe execution of asynchronous Playwright tasks inside Jupyter notebooks by running coroutines in an isolated background thread with a dedicated event loop. On Windows, a Proactor event loop policy is applied to ensure proper subprocess handling.
#
# This approach improves stability, compatibility, and error isolation when running browser automation workflows.

# %%
# Helper function to safely run async Playwright coroutines inside Jupyter

def run_coro_in_thread(coro):
    import threading
    import queue

    # Suppress deprecation warnings
    warnings.filterwarnings("ignore", category=DeprecationWarning)

    # Thread-safe queue to retrieve execution results
    q = queue.Queue()

    def _runner():
        try:
            # Apply Windows-specific Proactor event loop policy for subprocess support
            if sys.platform.startswith("win"):
                asyncio.set_event_loop_policy(asyncio.WindowsProactorEventLoopPolicy())

            # Create and assign a new isolated event loop
            loop = asyncio.new_event_loop()
            asyncio.set_event_loop(loop)

            try:
                result = loop.run_until_complete(coro)
                q.put(("ok", result))
            finally:
                loop.close()

        except BaseException as e:
            q.put(("err", e))

    # Run coroutine in background thread
    t = threading.Thread(target=_runner, daemon=True)
    t.start()

    # Retrieve execution result
    kind, val = q.get()

    if kind == "err":
        raise val

    return val

# %% [markdown]
# ### Scraping Configuration and Execution Overview
#
# This section defines the main scraping parameters and execution workflow for collecting MinCIT draft decree documents (2018–2025).
#
# ### Key Features
# - Year-based navigation with multiple URL fallbacks per period.
# - Automated browser-based downloads using Playwright.
# - Polite crawling strategy with navigation and download delays.
# - Robust error handling with retry and backoff logic.
# - Automatic generation of a CSV manifest to track downloaded files and metadata.
#
# ### Output
# - Downloaded documents are stored locally in year-specific folders.
# - A cumulative `downloads_manifest.csv` file is created to support traceability and reproducibility.
#
# ### Execution
# The pipeline is executed asynchronously through Playwright and launched inside Jupyter using a dedicated event loop wrapper to ensure platform compatibility.

# %%
# ================== DOWNLOAD CONFIGURATION ==================

TARGET_YEARS = range(2018, 2026)  # Includes 2017 due to site structure; target period is 2018–2025
BASE_PREFIX = "https://www.mincit.gov.co/normatividad/proyectos-de-normatividad"

# Local folder where downloaded documents will be stored
DOWNLOAD_FOLDER = os.path.join("data_raw", "mincit")

os.makedirs(DOWNLOAD_FOLDER, exist_ok=True)

# Navigation and download pacing (polite scraping)
NAV_DELAY_SEC = 1.2              # Delay between page navigations
DL_DELAY_SEC = 1.0               # Delay between individual downloads

# Download robustness parameters
MAX_CONCURRENT_DOWNLOADS = 3     # Maximum concurrent downloads (reserved for future use)
MAX_RETRIES = 3                  # Number of retry attempts per download
BACKOFF_BASE = 1.8               # Exponential backoff factor
REQUEST_TIMEOUT = 120            # Request timeout (seconds)
CHUNK_SIZE = 1024 * 256          # Streaming chunk size (256 KB)
VERIFY_SSL = True                # Keep enabled in production environments

# =============================================================

def candidate_year_urls(year: int):
    """
    Generate candidate landing page URLs for a given year.
    The MinCIT website uses different naming patterns (singular/plural and historical paths).
    """
    return [
        f"{BASE_PREFIX}/proyectos-de-decreto-{year}",
        f"{BASE_PREFIX}/proyectos-de-decretos-{year}",
        f"{BASE_PREFIX}/proyecto-de-decretos-{year}",
        f"{BASE_PREFIX}/historial-proyectos/proyectos-de-decreto-{year}",
        f"{BASE_PREFIX}/historial-proyectos/proyectos-de-decretos-{year}",
    ]

def sanitize_filename(name: str) -> str:
    """
    Remove invalid filesystem characters to ensure cross-platform compatibility.
    """
    name = re.sub(r'[\\/*?:"<>|]', "_", name)
    return name.strip()

def filename_from_cd(cd_header: str) -> str | None:
    """
    Extract filename from the Content-Disposition HTTP header, if available.
    """
    if not cd_header:
        return None

    m = re.search(r'filename\*?=(?:UTF-8\'\')?"?([^\";]+)"?', cd_header, re.IGNORECASE)
    if not m:
        return None

    return sanitize_filename(unquote(m.group(1)))

def is_pdf_response(resp: requests.Response) -> bool:
    """
    Check whether the HTTP response corresponds to a PDF file.
    """
    ct = (resp.headers.get("Content-Type") or "").lower()
    return "application/pdf" in ct or ct.endswith("/pdf")

async def polite_sleep(seconds: float):
    """
    Introduce controlled delays to reduce server load and avoid aggressive scraping.
    """
    await asyncio.sleep(seconds)

async def download_pdf(url: str, out_path: str, session: requests.Session) -> dict | None:
    """
    Download a PDF file using HTTP streaming and return metadata.
    Returns None if the download fails.
    """
    for attempt in range(1, MAX_RETRIES + 1):
        try:
            with session.get(
                url,
                timeout=REQUEST_TIMEOUT,
                stream=True,
                verify=VERIFY_SSL
            ) as r:

                r.raise_for_status()

                # Validate PDF content type (fallback: allow .pdf extension)
                if not is_pdf_response(r) and not url.lower().endswith(".pdf"):
                    print(f"    ! Non-PDF content detected (Content-Type={r.headers.get('Content-Type')}), skipping.")
                    return None

                cd_name = filename_from_cd(r.headers.get("Content-Disposition", ""))
                final_path = os.path.join(os.path.dirname(out_path), cd_name) if cd_name else out_path

                total = 0
                with open(final_path, "wb") as f:
                    for chunk in r.iter_content(chunk_size=CHUNK_SIZE):
                        if chunk:
                            f.write(chunk)
                            total += len(chunk)

                size_mb = total / (1024 * 1024)
                print(f"    ✓ Saved {os.path.basename(final_path)} ({size_mb:.2f} MB)")

                return {
                    "saved_path": os.path.abspath(final_path),
                    "bytes": total,
                    "filename": os.path.basename(final_path),
                    "source_url": url,
                }

        except Exception as e:
            if attempt < MAX_RETRIES:
                wait = (BACKOFF_BASE ** (attempt - 1))
                print(f"    ! Attempt {attempt}/{MAX_RETRIES} failed: {e} -> retrying in {wait:.1f}s")
                await asyncio.sleep(wait)
            else:
                print(f"    ✗ Download failed after {MAX_RETRIES} attempts: {e}")
                return None

async def scrape_year(page, year: int) -> int:
    """
    Scrape all available draft decree documents for a given year.
    Returns the number of successfully downloaded files.
    """
    downloaded = 0
    manifest_rows = []  # Accumulate metadata rows for the current year

    for url in candidate_year_urls(year):
        try:
            await page.goto(url, timeout=90000, wait_until="load")
            await polite_sleep(NAV_DELAY_SEC)

            # Scroll to trigger lazy-loaded content
            await page.evaluate("window.scrollTo(0, document.body.scrollHeight)")
            await polite_sleep(0.6)

            # Primary selector for "Ver documento" links
            anchors = await page.get_by_role(
                "link",
                name=re.compile(r"ver\s*documento", re.I)
            ).all()

            if not anchors:
                anchors = await page.locator('a:has-text("Ver documento")').all()

            if not anchors:
                # Fallback selector for any link/button mentioning "documento"
                anchors = await page.locator(
                    'a, button, [role="link"]',
                    has_text=re.compile(r"documento", re.I)
                ).all()

            if not anchors:
                print(f"  -> {year}: no 'Ver documento' links found at {url}")
                continue

            print(f"  -> {year}: {len(anchors)} documents found at {url}")

            year_folder = os.path.join(DOWNLOAD_FOLDER, f"{year}")
            os.makedirs(year_folder, exist_ok=True)

            # Sequential downloads (human-like behavior)
            for i, a in enumerate(anchors, start=1):
                await polite_sleep(DL_DELAY_SEC)

                try:
                    # Wait for browser download event triggered by click
                    async with page.expect_download(timeout=60000) as dl_info:
                        await a.click(button="left")

                    download = await dl_info.value

                    suggested = download.suggested_filename or f"decreto_{i}.pdf"
                    fname = sanitize_filename(suggested)
                    final_path = os.path.join(year_folder, fname)

                    await download.save_as(final_path)

                    size_bytes = os.path.getsize(final_path)
                    downloaded += 1

                    print(f"    ✓ Saved {fname} ({size_bytes / 1024 / 1024:.2f} MB)")

                    manifest_rows.append({
                        "saved_path": os.path.abspath(final_path),
                        "bytes": size_bytes,
                        "filename": fname,
                        "source_url": download.url or "",
                        "year": int(year),
                        "landing_page": url,
                    })

                except Exception as e:
                    print(f"    ! Download failed for link #{i}: {e}")

            # Append yearly batch to manifest CSV
            if manifest_rows:
                df = pd.DataFrame(manifest_rows)

                csv_path = os.path.join(DOWNLOAD_FOLDER, "downloads_manifest.csv")
                header = not os.path.exists(csv_path)

                df.to_csv(
                    csv_path,
                    mode="a",
                    header=header,
                    index=False,
                    encoding="utf-8"
                )

                print(f"  -> Manifest updated: {csv_path} (+{len(df)} rows)")

            # Stop searching alternative URLs if this one succeeded
            return downloaded

        except Exception as e:
            print(f"  -> {year}: error while processing {url}: {e}")

    print(f"  -> {year}: no valid landing page found.")
    return downloaded

async def main():
    """
    Main orchestration function that launches the browser,
    iterates over target years, and aggregates download statistics.
    """
    total = 0

    async with async_playwright() as p:

        browser = await p.chromium.launch(headless=True)

        context = await browser.new_context(
            user_agent=(
                "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 "
                "(KHTML, like Gecko) Chrome/126.0 Safari/537.36"
            ),
            ignore_https_errors=True
        )

        page = await context.new_page()

        for year in TARGET_YEARS:
            print(f"\n=== YEAR {year} ===")
            count = await scrape_year(page, year)
            total += count

        await browser.close()

    print("\n--- PROCESS COMPLETED ---")
    print(f"Total documents downloaded: {total}")
    print(f"Output folder: {DOWNLOAD_FOLDER}")

# Entry point for execution inside Jupyter/Colab environments
# await main()
run_coro_in_thread(main())
# Out:
# === YEAR 2018 ===
#   -> 2018: no 'Ver documento' links found at https://www.mincit.gov.co/normatividad/proyectos-de-normatividad/proyectos-de-decreto-2018
#   -> 2018: no 'Ver documento' links found at https://www.mincit.gov.co/normatividad/proyectos-de-normatividad/proyectos-de-decretos-2018
#   -> 2018: 32 documents found at https://www.mincit.gov.co/normatividad/proyectos-de-normatividad/proyecto-de-decretos-2018
#     ✓ Saved DECRETO-NUMERO-DE-2018.pdf (0.42 MB)
#     ✓ Saved DECRETO-2.pdf (0.74 MB)
#     ✓ Saved DECRETO-3.pdf (0.46 MB)
#     ✓ Saved image2019-02-25-104030.pdf (5.95 MB)
#     ✓ Saved DECRETO-5.pdf (0.30 MB)
#     ✓ Saved DECRETO-6.pdf (0.42 MB)
#     ✓ Saved DECRETO-7.pdf (0.30 MB)
#     ✓ Saved DECRETO-8.pdf (0.32 MB)
#     ✓ Saved DECRETO-9.pdf (0.39 MB)
#     ✓ Saved DECRETO-10.pdf (0.20 MB)
#     ✓ Saved DECRETO-11.pdf (0.42 MB)
#     ✓ Saved DECRETO-12.pdf (0.49 MB)
#     ✓ Saved DECRETO-13.pdf (0.44 MB)
#     ✓ Saved DECRETO-14.pdf (0.23 MB)
#     ✓ Saved DECRETO-15.pdf (0.23 MB)
#     ✓ Saved DECRETO-16.pdf (0.36 MB)
#     ✓ Saved DECRETO-17.pdf (0.15 MB)
#     ✓ Saved 1-Proyecto-de-Decreto-de-Tamano-Empresarial-VF.pdf (0.49 MB)
#     ✓ Saved DECRETO-19.pdf (0.24 MB)
#     ✓ Saved DECRETO-20.pdf (0.24 MB)
#     ✓ Saved DECRETO-21.pdf (0.27 MB)
#     ✓ Saved DECRETO-22.pdf (0.32 MB)
#     ✓ Saved DECRETO-23.pdf (0.52 MB)
#     ✓ Saved DECRETO-24.pdf (0.11 MB)
#     ✓ Saved DECRETO-25.pdf (0.38 MB)
#     ✓ Saved DECRETO-26.pdf (0.31 MB)
#     ✓ Saved DECRETO-27.pdf (0.25 MB)
#     ✓ Saved DECRETO-28.pdf (0.17 MB)
#     ✓ Saved DECRETO-29.pdf (0.19 MB)
#     ✓ Saved DECRETO-30.pdf (0.29 MB)
#     ✓ Saved DECRETO-31.pdf (0.11 MB)
#     ✓ Saved DECRETO-32.pdf (0.61 MB)
#   -> Manifest updated: data_raw\mincit\downloads_manifest.csv (+32 rows)
#
# === YEAR 2019 ===
#   -> 2019: no 'Ver documento' links found at https://www.mincit.gov.co/normatividad/proyectos-de-normatividad/proyectos-de-decreto-2019
#   -> 2019: 64 documents found at https://www.mincit.gov.co/normatividad/proyectos-de-normatividad/proyectos-de-decretos-2019
#     ✓ Saved DIC-26-19-PROYECTO-DE-DECRETO-COMPETENCIAS-LABORALES.pdf (0.35 MB)
#     ✓ Saved PD-Infraestructura.pdf (0.37 MB)
#     ✓ Saved Proyecto-de-decreto-Por-el-cual-se-derogan-unos-decretos.pdf (0.27 MB)
#     ✓ Saved Proyecto-Modificacion-Decreto-1595-de-2015.pdf (0.61 MB)
#     ✓ Saved VFF-Formato-proyecto-de-decreto-Insolvencia-22-11-2019.pdf (0.50 MB)
#     ✓ Saved PD-Tarifas-Registro-mercantil-1nov19.pdf (0.56 MB)
#     ✓ Saved Por-el-cual-se-prorroga-la-vigencia-del-arancel-de-aduanas-para-determinadas-Subpartidas-del-Capitulo-64.pdf (0.38 MB)
#     ✓ Saved Proyecto-de-decreto-Parte-3-del-Libro-I-del-Decreto-Unico-Reglamen.pdf (0.43 MB)
#     ✓ Saved PD-Tarifas-Registro-mercantil-10oct19.pdf (0.56 MB)
#     ✓ Saved Proyecto-de-decreto-Astilleros.pdf (0.46 MB)
#     ✓ Saved 16-9-2019-Proyecto-de-Decreto-NIIF-NIA-Consulta-publica.pdf (0.46 MB)
#     ✓ Saved Decreto-Guias-de-turismo.pdf (0.41 MB)
#     ✓ Saved Proyecto-de-decreto-IMPUESTO-AL-TURISMO-22-09-2019.pdf (0.40 MB)
#     ✓ Saved Proyecto-decreto-BIC-v-23-09-2019-vF-REV.pdf (0.24 MB)
#     ✓ Saved Proyecto-de-Decreto-Avaluadore.pdf (0.46 MB)
#     ✓ Saved Proyecto-decreto-desgravacion-arancelaria-TLC-Col-ISRAEL-Sept-20-2019-P.pdf (0.99 MB)
#     ✓ Saved Proyecto-de-decreto-inclusion-de-unas-subpartidas-arancelarias-en-la-lista-de-bienes-de-capi.pdf (0.37 MB)
#     ✓ Saved pyto-de-decreto-diferimiento-electrodomesticos-ajustado.pdf (0.27 MB)
#     ✓ Saved Pyto-de-decreto-desdoblamientos-y-Colceramica.pdf (0.28 MB)
#     ✓ Saved 2019-09-04-Decreto-Patrimonios-Autonomos.pdf (0.42 MB)
#     ✓ Saved Proyecto-Decreto-Aplicaicon-de-Derechos-Compensatorios-VF.pdf (0.67 MB)
#     ✓ Saved Decreto-Artesanias-de-Colombia-Delegado-de-MInistro.pdf (0.18 MB)
#     ✓ Saved PytoDecretoVehiculos.pdf (0.37 MB)
#     ✓ Saved Proyecto-Decreto-PV-Sistemas-Especiales-de-Importacion-–-Exportaciones.pdf (0.24 MB)
#     ✓ Saved Pyto-de-decreto-chatarra-final-observaciones-OJ.pdf (0.27 MB)
#     ✓ Saved PytoD-ActualizacionD272.pdf (0.57 MB)
#     ✓ Saved Proyecto-de-Decreto-Sociedades-no-Operativas-V3.pdf (0.34 MB)
#     ✓ Saved Decreto-plazos-contribucio-n-turismo-21-08-2019.pdf (0.38 MB)
#     ✓ Saved PytoD-Mod-D-1027.pdf (0.37 MB)
#     ✓ Saved 2019-07-24-Decreto-Composicion-Opcion-3-1.pdf (0.22 MB)
#     ✓ Saved PD-CIRCULACION-FACTURA-ELECTRONICA-DE-VENTA-COMO-TITULO-VALOR-Consulta-publica.pdf (0.73 MB)
#     ✓ Saved 2019jul27-Decreto-plazos-contribucion-turismo.pdf (0.06 MB)
#     ✓ Saved PD-Art-39L1480-19072019.pdf (0.53 MB)
#     ✓ Saved 1Pyto-Decreto-Prof-COL-ES-V3-Ajustada-OAJ-22-Jul-2019.pdf (0.38 MB)
#     ✓ Saved Proyecto-de-decreto-desdoblamientos.pdf (0.34 MB)
#     ✓ Saved Proyecto-decreto-BIC-v-19-07-2019.pdf (0.24 MB)
#     ✓ Saved Pyto-Dcto-ATI-Rev-040619.pdf (0.55 MB)
#     ✓ Saved Proyecto-ProrrogaMaquinaria.pdf (0.24 MB)
#     ✓ Saved DECRETO-normas-obsoletas-DUR-1074-de-2015.pdf (0.09 MB)
#     ✓ Saved Decreto-Intervencion-Supersociedades.pdf (0.64 MB)
#     ✓ Saved Decreto-Ampliacion-TRH-28-06-2019.pdf (0.29 MB)
#     ✓ Saved Pyto-Dcto-ATI-Rev-040619.pdf (0.55 MB)
#     ✓ Saved Proyecto-decreto-megainversin-ajustado-ZF-V17062019.pdf (0.36 MB)
#     ✓ Saved 201900604Formato-proyecto-de-decreto.pdf (0.72 MB)
#     ✓ Saved 2019-05-28-Propuesta-decreto-composicion-JA-PTP.pdf (0.10 MB)
#     ✓ Saved Proyecto-de-Decreto-UV523201944513-PM.pdf (0.39 MB)
#     ✓ Saved PROYECTO-ANDJE.pdf (0.15 MB)
#     ✓ Saved 190524-DGRESS-Proyecto-de-Decreto-Paso-a-UGPP.pdf (0.09 MB)
#     ✓ Saved Decreto-de-implementacion-de-los-articulos-274-y-275-del-PND-Consolidado.pdf (0.32 MB)
#     ✓ Saved Proyecto-de-Decreto-Prorrogas-ZF-27-de-mayo-publicacion.pdf (0.44 MB)
#     ✓ Saved PytoD-Mod-D-1027.pdf (0.32 MB)
#     ✓ Saved PytoD-ActualizacionD272.pdf (0.79 MB)
#     ✓ Saved Proyecto-Decreto-Modificatorio-299-de-1995-Comentarios-JV-OJ.pdf (0.36 MB)
#     ✓ Saved Proyecto-ProrrogaMaquinaria.pdf (0.24 MB)
#     ✓ Saved PROYECTO-DECRETO-IMPO-TURISMO-VICE-DASYP-2-05-2019.pdf (0.37 MB)
#     ✓ Saved P-D-Guias-de-Turismo-29-04-2019.pdf (0.41 MB)
#     ✓ Saved Proyecto-de-decreto-desdoblamientos.pdf (0.34 MB)
#     ✓ Saved Pyto-Decreto-Profundizacion-COL-GT-VDef.pdf (0.54 MB)
#     ✓ Saved Proyecto-decreto-BIC-v-13-06-2019-Post-abogacia.pdf (0.38 MB)
#     ✓ Saved Por-el-cual-se-adiciona-el-Capitulo-13-y-la-Seccion-1-al-Decreto-1074-de-2015-reglamenta-el-paragrafo-2-del-articulo-3-de-la-Ley-1816-de.pdf (0.27 MB)
#     ✓ Saved proyecto-de-decreto-medida-salvaguardia-barras-de-acero-ajustado-con-cambios-DIAN-enero-30-19-limpio.pdf (0.28 MB)
#     ✓ Saved Proyecto-de-Decreto-Premio-Colombiano-a-la-Calidad-para-la-Exportacion.pdf (0.63 MB)
#     ✓ Saved PROYECTO-PLAN-VALLEJO-INCORPORA-COMENTARIOS-DIAN-enero-17-19-LF.pdf (0.71 MB)
#     ✓ Saved Proyecto-de-decreto.pdf (8.63 MB)
#   -> Manifest updated: data_raw\mincit\downloads_manifest.csv (+64 rows)
#
# === YEAR 2020 ===
#   -> 2020: no 'Ver documento' links found at https://www.mincit.gov.co/normatividad/proyectos-de-normatividad/proyectos-de-decreto-2020
#   -> 2020: 49 documents found at https://www.mincit.gov.co/normatividad/proyectos-de-normatividad/proyectos-de-decretos-2020
#     ✓ Saved 16-12-2020-PD-Tarifas-VF.pdf (0.23 MB)
#     ✓ Saved 20-11-20-Proyecto-de-decreto-sobre-importacion-de-vehiculos.pdf (0.14 MB)
#     ✓ Saved 19-11-20-PD-ZFs.pdf (0.55 MB)
#     ✓ Saved Proy-Modif-Dec-2147-16-ZFs-18112020-ingles.pdf (0.71 MB)
#     ✓ Saved 17-11-20-PD-Captacion.pdf (0.09 MB)
#     ✓ Saved 13-11-20-PD-Asbesto.pdf (1.77 MB)
#     ✓ Saved 13-11-20-PD-PLANTA-SS.pdf (0.91 MB)
#     ✓ Saved 13-11-20-PD-ESTRUCTURA-SS.pdf (14.55 MB)
#     ✓ Saved 11-11-20-PD-Motos-Electricas.pdf (0.08 MB)
#     ✓ Saved 10-11-20-PD-Prorroga-Decreto-2279-de-2019-Aranceles-de-Calzado.pdf (0.08 MB)
#     ✓ Saved 06-11-20-PD-Plazos-Justos.pdf (0.11 MB)
#     ✓ Saved 28-10-20-PD-IVC-Empresas-Unipersonales-Salud.pdf (0.13 MB)
#     ✓ Saved 26-10-20-PD-Minamata.pdf (0.18 MB)
#     ✓ Saved PD-Prohibicion-de-exportaciones-de-productos-Covid-19-01102020-V05-CP-MS.pdf (0.15 MB)
#     ✓ Saved Proyecto-de-decreto-exlcusion-de-contingente-para-la-chatarra-no-ferrosa.pdf (0.44 MB)
#     ✓ Saved 31-08-20-PD-Trazabilidad-de-Alcohol-Potable-y-no-Potable.pdf (3.64 MB)
#     ✓ Saved 19-08-20-PD-Antidumping.pdf (0.34 MB)
#     ✓ Saved 18-08-2020-PD-Depuracion-Normativa-DUR-CIT.pdf (0.10 MB)
#     ✓ Saved 14-08-20-PD-Modificatorio-1910.pdf (2.60 MB)
#     ✓ Saved 06-08-20-PD-Reglamentario-del-772.pdf (0.10 MB)
#     ✓ Saved 04-08-20-PD-Reversion-de-Pagos.pdf (0.10 MB)
#     ✓ Saved 31-07-20-Reforma-AIN-proyecto-de-decreto.pdf (0.17 MB)
#     ✓ Saved 30-07-2020-PD-NIIF-16.pdf (0.07 MB)
#     ✓ Saved 29-07-20-PD-SEIEX.pdf (0.09 MB)
#     ✓ Saved 16-07-20-PD-Exclusion-de-Prohibicion-de-Exportacion-Decreto-462-de-2020.pdf (0.12 MB)
#     ✓ Saved 10-07-20-PD-Martillo-Electronico.pdf (0.10 MB)
#     ✓ Saved 02-07-20-PD-Desdoblamiento-Aguacates-y-Tapabocas.pdf (0.61 MB)
#     ✓ Saved PD-CCNeiva-REV-OAJ.pdf (0.49 MB)
#     ✓ Saved 26-06-20-Decreto-Astilleros-27jun2020.pdf (5.19 MB)
#     ✓ Saved Proyecto-Decreto-Exclusion-de-prohibicion-de-expo-de-varios-productos-V11-17062020.pdf (0.10 MB)
#     ✓ Saved 09-06-20-PD-Prorroga-de-Contribucion-Parafiscal.pdf (0.73 MB)
#     ✓ Saved 11-05-20-PD-Reversion-de-Pagos-VF.pdf (1.47 MB)
#     ✓ Saved Decreto-por-el-cual-se-modifica-parcialmente-el-arancel-de-aduanas.pdf (0.52 MB)
#     ✓ Saved Decreto-II-proyecto-disposiciones-transitorias-comercio-turismo-zonas-francas.pdf (0.24 MB)
#     ✓ Saved Decreto-I-proyecto-importacion-exportacion-consumidor-turismo-y-zonas-francas.pdf (0.29 MB)
#     ✓ Saved Decreto-por-el-cual-se-modifica-parcialmente-el-arancel-de-aduanas-Resina-PET.pdf (0.51 MB)
#     ✓ Saved Por-el-cual-se-modifica-parcialmente-el-arancel-de-aduanas-para-la-importacion-de-insumos-de-salud.pdf (0.54 MB)
#     ✓ Saved Proyecto-Decreto-Deroga-D-1027-y-modif-D-272-07052020.pdf (0.45 MB)
#     ✓ Saved PD-Reglamentario-Insolvencia-DL560-29-04-30-VF.pdf (0.30 MB)
#     ✓ Saved Proyecto-Decreto-creacion-de-cargos-permanetes-SIC-marzo-2020.pdf (0.24 MB)
#     ✓ Saved PD-Trigo-y-Sodio-12-03-20.pdf (0.05 MB)
#     ✓ Saved PD-Chatarra-12-03-20-VF.pdf (0.05 MB)
#     ✓ Saved PD-Factura-Electronica-03-03-20.pdf (0.18 MB)
#     ✓ Saved PD-Por-el-cual-se-modifica-el-arancel-de-aduanas-publicacion.pdf (0.36 MB)
#     ✓ Saved PD-ACICAM-y-FEDEGAN-06-02-20.pdf (0.09 MB)
#     ✓ Saved PD-Liquidacion-de-Sociedades-No-Operativas-05-02-20.pdf (0.07 MB)
#     ✓ Saved P-D-Impuesto-al-Turismo-27-01-20.pdf (0.22 MB)
#     ✓ Saved PD-Desgravacion-Arancelaria-TLC-Israel-22-01-20.pdf (1.98 MB)
#     ✓ Saved PD-Guias-de-Turismo-21-01-20FP.pdf (0.43 MB)
#   -> Manifest updated: data_raw\mincit\downloads_manifest.csv (+49 rows)
#
# === YEAR 2021 ===
#   -> 2021: 51 documents found at https://www.mincit.gov.co/normatividad/proyectos-de-normatividad/proyectos-de-decreto-2021
#     ✓ Saved 06-12-21-PD-ONAC.pdf (0.10 MB)
#     ✓ Saved 19-11-21-PD-Delacion.pdf (0.16 MB)
#     ✓ Saved 17-11-21-PD-Derechos-Compensatorios.pdf (9.06 MB)
#     ✓ Saved 17-11-21-PD-Unificacion-de-Fuentes-de-Emprendimiento.pdf (2.50 MB)
#     ✓ Saved 08-11-21-PD-VII-Enmienda.pdf (254.04 MB)
#     ✓ Saved 15-10-21-PD-Fiduciaria-FONTUR.pdf (0.14 MB)
#     ✓ Saved 15-10-21-PD-SIFAI-VUI.pdf (0.27 MB)
#     ✓ Saved 08-10-21-PD-Modificacion-Mercurio.pdf (3.99 MB)
#     ✓ Saved 08-10-21-PD-Impuesto-Diferido-Limpio.pdf (0.93 MB)
#     ✓ Saved 05-10-21-PD-SIGR-VUCE.pdf (3.64 MB)
#     ✓ Saved 01-10-21-PD-Acero.pdf (0.07 MB)
#     ✓ Saved 28-09-21-PD-RNT.pdf (5.54 MB)
#     ✓ Saved 17-09-21-PD-Modifica-HNM.pdf (0.10 MB)
#     ✓ Saved 15-09-21-PD-Atractivos-Puntos-Control-y-Carga-Limpio.pdf (0.19 MB)
#     ✓ Saved 31-08-2021-PD-Parques-Agroturismo-y-Ecoturismo.pdf (0.13 MB)
#     ✓ Saved 31-08-2021-PD-Empresas-de-Tiempo-Compartido.pdf (0.10 MB)
#     ✓ Saved 18-08-21-PD-Contabilidad-Simplificada.pdf (0.11 MB)
#     ✓ Saved 17-08-21-PD-Firma-Electronica-y-Digital.pdf (1.65 MB)
#     ✓ Saved 17-08-2021-PD-Guias-de-Turismo.pdf (0.11 MB)
#     ✓ Saved 10-08-21-PD-Sandbox.pdf (0.17 MB)
#     ✓ Saved 10-08-21-PD-Normas-Corporativas-Vinculantes.pdf (0.11 MB)
#     ✓ Saved 29-07-21-PD-Franquicias.pdf (2.20 MB)
#     ✓ Saved 15-07-21-PD-Designacion-Presidente-del-CTCP-30jul2021.pdf (0.81 MB)
#     ✓ Saved 23-07-21-PD-Contingente-Automotor-23jul2021.pdf (0.12 MB)
#     ✓ Saved 24-06-2021-Borrador-PD-Apoyo-articulo-53-L2068-de-2020.pdf (0.18 MB)
#     ✓ Saved 01-06-21-PROYECTO-DECRETO-2021-considerandos-01062021-DCE-OALI-1-DIAN.pdf (0.14 MB)
#     ✓ Saved 18-05-21-PD-Reglamentacion-Articulo-25-Ley-de-Emprendimiento.pdf (0.09 MB)
#     ✓ Saved 13-05-21-PD-Definiciones.pdf (0.21 MB)
#     ✓ Saved 13-05-21-PD-MARTILLO-ELECTRONICO.pdf (0.19 MB)
#     ✓ Saved 22-04-21-PD-Chatarra-Ferrosa.pdf (0.08 MB)
#     ✓ Saved 21-04-21-PD-Vehiculos-Hibridos.pdf (0.07 MB)
#     ✓ Saved 12-04-21-PD-Consultorios-Empresariales.pdf (1.19 MB)
#     ✓ Saved 12-04-21-PD-Pigmentos.pdf (0.50 MB)
#     ✓ Saved Proyecto-Decreto-Equipos-APNEA.pdf (0.13 MB)
#     ✓ Saved Proyecto-Decreto-O2-y-concentradores.pdf (0.12 MB)
#     ✓ Saved 29-03-21-PD-Red-Angeles-Empresarios-y-Voluntariado.pdf (1.61 MB)
#     ✓ Saved 25-03-21-PD-CEmprende.pdf (1.68 MB)
#     ✓ Saved 25-03-21-PD-Fondos-Territoriales.pdf (3.05 MB)
#     ✓ Saved 24-03-2021-PD-Adopcion-de-Politica-de-Sostenibilidad-Turistica.pdf (0.69 MB)
#     ✓ Saved 10-03-21-PD-Confecciones.pdf (0.10 MB)
#     ✓ Saved 08-03-21-PD-NIIF-Enmiendas.pdf (0.30 MB)
#     ✓ Saved 03-03-21-PD-PET.pdf (0.07 MB)
#     ✓ Saved 26-02-21-PD-Sello-de-Accesibilidad.pdf (3.14 MB)
#     ✓ Saved 17-02-21-PD-Descuentos-Fiscales.pdf (0.15 MB)
#     ✓ Saved 11-02-21-PD-Contribucion-Parafiscal-Turismo.pdf (4.74 MB)
#     ✓ Saved 11-02-21-PD-Desdoblamiento-Vacunas.pdf (0.93 MB)
#     ✓ Saved 28-01-21-PD-Correccion-de-Errores-Ley-2069-de-2020.pdf (0.11 MB)
#     ✓ Saved 26-01-21-PD-Bonos.pdf (1.79 MB)
#     ✓ Saved 22-01-21-PD-Asambleas-2021.pdf (0.25 MB)
#     ✓ Saved 22-01-21-PD-Hipotesis-de-Negocio-en-Marcha.pdf (0.13 MB)
#     ✓ Saved 21-01-21-PD-Gastronomia.pdf (0.10 MB)
#   -> Manifest updated: data_raw\mincit\downloads_manifest.csv (+51 rows)
#
# === YEAR 2022 ===
#   -> 2022: 29 documents found at https://www.mincit.gov.co/normatividad/proyectos-de-normatividad/proyectos-de-decreto-2022
#     ✓ Saved 22-12-2022-PD-impuesto-diferido-renta-gan-ocasi-sin-CC.pdf (0.23 MB)
#     ✓ Saved 10-12-2022-PD-medidas-hurto-celulares.pdf (0.24 MB)
#     ✓ Saved 09-12-2022-PD-prorroga-arancel-calzado.pdf (0.20 MB)
#     ✓ Saved 22-11-2022-Proyecto-Decreto-modifica-272.pdf (0.21 MB)
#     ✓ Saved 21-11-2022-PD-Delegacion-IV-ESAL-dom-extranjero.pdf (0.21 MB)
#     ✓ Saved 17-11-2022-Proyecto-Decreto-Contingente-Chatarra-2022.pdf (0.39 MB)
#     ✓ Saved 01-11-2022-PD-Arancel-advalorem-confecciones.pdf (0.21 MB)
#     ✓ Saved 05-10-2022-PD-modificacion-Decreto-3303-de-2006.pdf (0.28 MB)
#     ✓ Saved 12-09-22-PD-Normas-de-Aseguramiento.pdf (0.21 MB)
#     ✓ Saved 22-06-2022-Proyecto-Dcto-reduccion-arancel-fertilizantes-Decto-894.pdf (0.28 MB)
#     ✓ Saved 22-06-2022-Proyecto-Dcto-reduccion-arancel-mani-Decreto-882-de-2020.pdf (0.20 MB)
#     ✓ Saved 21-06-2022-Proyecto-de-Decreto-gobierno-corporativo-camaras.pdf (0.24 MB)
#     ✓ Saved 07-06-2022-Proyecto-Decreto-desdoblamiento-barcos.pdf (0.20 MB)
#     ✓ Saved 01-06-2022-PD-Modificacion-Vigencia-Decreto-1880-IAMAS-SPC.pdf (0.22 MB)
#     ✓ Saved 23-05-2022-PROYECTO-DECRETO-EXCLUSION-FLETES-Y-GASTOS-CONEXOS-sesion356.pdf (0.22 MB)
#     ✓ Saved 23-05-2022-Proyecto-lista-de-bienes-de-capital.pdf (0.23 MB)
#     ✓ Saved 05-05-2022-Proyecto-Decreto-Trigo-30042022-rev-EF.pdf (0.11 MB)
#     ✓ Saved 04-05-2022-20220503-PD-NIIF-Modificaciones-y-enmiendas-vers-publicacion.pdf (0.22 MB)
#     ✓ Saved 05-04-2022-PROYECTO-DECRETO-EXCLUSION-FLETES-Y-GASTOS-CONEXOS.pdf (0.23 MB)
#     ✓ Saved 20220330-PD-modificacion-Decreto-419-de-2021.pdf (0.45 MB)
#     ✓ Saved 22-03-2022-PD-modificacion-requisitos-de-procedencia-fondos-territoriales.pdf (0.21 MB)
#     ✓ Saved 04-03-2022-PD-modificacion-arancel-productos-Insumos-Agropecuarios-MADR-02-03-2022.pdf (0.30 MB)
#     ✓ Saved 18-02-2022-Proyecto-Decreto-Implementacion-tlc-Col-UK.pdf (1.27 MB)
#     ✓ Saved 17-02-2022-PD-modificacion-arancel-productos-canasta-basica-e-insumos.pdf (0.22 MB)
#     ✓ Saved 14-02-2022-Proyecto-Decreto-Sello-Creo-en-Ti.pdf (0.43 MB)
#     ✓ Saved 11-02-2022-PD-teletrabajo-ZF.pdf (0.31 MB)
#     ✓ Saved 1-02-2022-PD-prorroga-plan-vallejo-expres.pdf (0.37 MB)
#     ✓ Saved 27-01-2022-PD-correccion-yerro-dec-1845.pdf (0.31 MB)
#     ✓ Saved 25-01-22-PD-modificacion-decreto-1644-de-2021.pdf (0.22 MB)
#   -> Manifest updated: data_raw\mincit\downloads_manifest.csv (+29 rows)
#
# === YEAR 2023 ===
#   -> 2023: 32 documents found at https://www.mincit.gov.co/normatividad/proyectos-de-normatividad/proyectos-de-decreto-2023
#     ✓ Saved 18-12-2023-PD-modifica-paragrafo-del-articulo-2-2-3-8-3-2-del-Decreto-1074-de-2015-SIED.pdf (0.14 MB)
#     ✓ Saved 07-12-2023-PD-Vehiculos-Hibridos.pdf (0.13 MB)
#     ✓ Saved 27-11-2023-PD-modificiacion-Decreto-2025-de-2015.pdf (0.22 MB)
#     ✓ Saved 20-11-2023-PD-reglamenta-RTPP-de-Colombia.pdf (0.19 MB)
#     ✓ Saved 31-10-2023-PD-Por-el-cual-se-modifica-parcialmente-el-Decreto-3303-de-2006.pdf (0.18 MB)
#     ✓ Saved 31-10-2023-PD-modifica-Comite-de-practicas-comerciales.pdf (0.17 MB)
#     ✓ Saved 30-10-2023-PD-Nuevo-modelo-tarifario-registro-mercantil.pdf (0.51 MB)
#     ✓ Saved 27-10-2023-PD-modificacion-arancel-de-aduanas-decision-906-CAN.pdf (0.12 MB)
#     ✓ Saved 24-10-2023-PD-Beneficios-por-colaboracion.pdf (0.23 MB)
#     ✓ Saved 19-10-2023-PD-Restablecimiento-Arancel-Decreto-272-de-2018-Sesion-365.pdf (0.20 MB)
#     ✓ Saved 19-10-2023-PD-Arancel-Alambres-Sesion-365.pdf (0.10 MB)
#     ✓ Saved 19-10-2023-PD-zonas-francas-mixtas.pdf (0.31 MB)
#     ✓ Saved 17-10-2023-PD-DEBERES-ADMINISTRADORES-CONFLICTO-DE-INTERESES.pdf (0.32 MB)
#     ✓ Saved 11-10-2023-PD-Creacion-Camara-de-Comercio-Soacha.pdf (0.32 MB)
#     ✓ Saved 20-09-2023-PD-apnea-oxigeno-y-mani.pdf (0.22 MB)
#     ✓ Saved 29-08-2023-PD-Incorporacion-NIIF-17-contrato-de-Seguro.pdf (0.99 MB)
#     ✓ Saved 25-08-2023-PD-PROFIA.pdf (0.49 MB)
#     ✓ Saved 25-08-2023-PD-Funcionamiento-del-Consejo-Nacional-de-la-Economia-Popular.pdf (0.22 MB)
#     ✓ Saved 25-08-2023-PD-Organizacion-y-funcionamiento-del-Sistema-Nacional-de-Competitividad-e-Innovacion-SNCI.pdf (0.33 MB)
#     ✓ Saved 28-06-2023-PD-planeacion-y-descentralizacion-del-turismo.pdf (0.33 MB)
#     ✓ Saved 08-06-2023-PD-IAMAS.pdf (0.38 MB)
#     ✓ Saved 31-05-2023-PD-Plan-internacionalizacion-zonas-francas.pdf (0.39 MB)
#     ✓ Saved 29-05-2023-PD-NIA-701.pdf (0.22 MB)
#     ✓ Saved 10-05-2023-PD-modificacion-decreto-1074-subsidios-a-prestadores-turisticos.pdf (0.31 MB)
#     ✓ Saved 05-05-2023-PD-modifica-Decreto-1074-2015-Auxiliares-de-la-Justicia-VF.pdf (0.37 MB)
#     ✓ Saved 28-04-2023-PD-modificacion-entrega-Premio-Innova.pdf (0.20 MB)
#     ✓ Saved 26-04-2023-PD-Contingente-arancelario-IAMAS.pdf (0.26 MB)
#     ✓ Saved 25-04-2023-PD-Vehiculos-Hibridos-sesion-363.pdf (0.22 MB)
#     ✓ Saved 24-04-2023-PD-reglamento-Ley-915-San-Andres.pdf (0.29 MB)
#     ✓ Saved 03-04-2023-PD-Insumos-Agropecuarios-2023.pdf (0.21 MB)
#     ✓ Saved 25-01-2023-PD-Modificacion-del-arancel-de-aduanas-desdoblamiento.pdf (0.29 MB)
#     ✓ Saved 10-01-2023-PD-modifica-el-Decreto-1100-de-2020.pdf (0.07 MB)
#   -> Manifest updated: data_raw\mincit\downloads_manifest.csv (+32 rows)
#
# === YEAR 2024 ===
#   -> 2024: 35 documents found at https://www.mincit.gov.co/normatividad/proyectos-de-normatividad/proyectos-de-decreto-2024
#     ✓ Saved 31-12-2024-PD-condiciones-y-requisitos-para-la-declaratoria-de-existencia-de-zonas-francas-permanentes-especiales.pdf (0.36 MB)
#     ✓ Saved 26-12-2024-PD-reglamenta-el-Certificado-de-Reembolso-Tributario-CERT.pdf (0.96 MB)
#     ✓ Saved 26-12-2024-PD-modifica-parcialmente-el-Arancel-de-Aduanas-para-el-sector-automotor.pdf (0.30 MB)
#     ✓ Saved 17-12-2024-PD-medidas-para-la-prevencion-y-el-control-del-fraude-aduanero-en-las-importaciones-de-hilos-de-coser-de-fibras-sinteticas.pdf (0.26 MB)
#     ✓ Saved 31-12-2024-PD-participacion-camaras-de-comercio-programas-reindustrializacion-turismo-y-comercio-exterior.pdf (0.20 MB)
#     ✓ Saved 05-12-2024-PD-Decreto-272-del-13-de-febrero-de-2018-y-el-Arancel-de-Aduanas.pdf (0.21 MB)
#     ✓ Saved 28-11-2024-PD-reglamenta-el-articulo-86-de-la-Ley-2294-de-2023.pdf (0.25 MB)
#     ✓ Saved 25-11-2024-PD-Arancel-de-Aduanas-para-la-importacion-de-insumos-agropecuarios.pdf (0.25 MB)
#     ✓ Saved 25-10-2024-PD-deroga-el-Decreto-1116-de-2017.pdf (0.24 MB)
#     ✓ Saved 18-10-2024-PD-personas-juridicas-sujetas-a-la-vigilancia-de-la-Superintendencia-de-Sociedades.pdf (0.32 MB)
#     ✓ Saved 02-10-2024-PD-Arancel-de-Aduanas-para-las-importaciones-de-lentes-de-otras-materias-para-gafas.pdf (0.25 MB)
#     ✓ Saved 24-09-2024-PD-PROFIA.pdf (0.72 MB)
#     ✓ Saved 23-08-2024-PD-se-corrige-un-error-formal-en-el-Decreto-2266-de-2023.pdf (0.11 MB)
#     ✓ Saved 12-08-2024-PD-modifican-los-umbrales-establecidos-en-el-Decreto-2218-de-2017.pdf (0.35 MB)
#     ✓ Saved 12-08-2024-PD-reglamentan-las-compensaciones-industriales-en-el-marco-de-la-Politica-de-Reindustrializacion.pdf (0.27 MB)
#     ✓ Saved 06-08-2024-PD-se-modifica-el-Decreto-1074-de-2015.pdf (0.35 MB)
#     ✓ Saved 05-08-2024-PD-se-reglamenta-parcialmente-la-Ley-2184-de-2022.pdf (0.52 MB)
#     ✓ Saved 30-07-2024-PD-reglamenta-el-articulo-86-de-la-Ley-2294-de-2023.pdf (0.26 MB)
#     ✓ Saved 22-07-2024-PD-corrige-un-error-formal-en-el-Decreto-2266-de-2023.pdf (0.11 MB)
#     ✓ Saved 22-07-2024-PD-Red-Colombiana-de-Metrologia.pdf (0.30 MB)
#     ✓ Saved 22-07-2024-PD-derechos-por-registro-y-renovacion-de-la-matricula-mercantil.pdf (0.41 MB)
#     ✓ Saved 18-06-2024-PD-diferimiento-arancelario-trigo.pdf (0.22 MB)
#     ✓ Saved 07-06-2024-PD-Restriccion-exportacion-carbon-a-Israel.pdf (0.16 MB)
#     ✓ Saved 05-06-2024-PD-Modificacion-Decreto-1074-de-2015.pdf (0.40 MB)
#     ✓ Saved 31-05-2024-PD-modifican-los-articulos-1-y-3-del-Decreto-3990-de-2010.pdf (0.43 MB)
#     ✓ Saved 30-05-2024-PD-Insumos-agropecuarios-SPC-CC.pdf (0.14 MB)
#     ✓ Saved 10-05-2024-PD-Certificado-de-Reembolso-Tributario-CERT.pdf (1.08 MB)
#     ✓ Saved 25-04-2024-PD-incorpora-la-Norma-de-Informacion-Financiera-NIIF-17.pdf (0.30 MB)
#     ✓ Saved 25-04-2024-PD-compensaciones-industriales-en-el-marco-de-la-Politica-de-Reindustrializacion.pdf (0.17 MB)
#     ✓ Saved 16-04-2024-PD-IAMAS-autopartes.pdf (0.33 MB)
#     ✓ Saved 20-03-2024-PD-TLC-Colombia-y-Costa-Rica.pdf (0.48 MB)
#     ✓ Saved 01-03-2024-PD-Desdoblamiento-hierbas-aromaticas-SPC-CC.pdf (0.24 MB)
#     ✓ Saved 27-02-2024-PD-Decreto-2266-de-2023-2.pdf (0.18 MB)
#     ✓ Saved 20-02-2024-PD-integracion-y-operacion-de-los-patrimonios-autonomos-iNNpulsa-Colombia-y-Colombia-Productiva.pdf (0.25 MB)
#     ✓ Saved 02-02-2024-PD-Programa-de-Fomento-para-la-Industria-Automotriz-y-se-deroga-el-Decreto-1122-de-2019.pdf (0.50 MB)
#   -> Manifest updated: data_raw\mincit\downloads_manifest.csv (+35 rows)
#
# === YEAR 2025 ===
#   -> 2025: 43 documents found at https://www.mincit.gov.co/normatividad/proyectos-de-normatividad/proyectos-de-decreto-2025
#     ✓ Saved 10-12-2025-PD-modifica-Decreto-1881-de-2021-y-se-incrementa-arancel-importaciones-baldosas-ceramicas.pdf (0.17 MB)
#     ✓ Saved 05-12-2025-PD-incremento-arancel-importaciones-sector-siderurgico-y-metalmecanico.pdf (0.13 MB)
#     ✓ Saved 03-12-2025-PD-umbrales-arancel-aduanas.pdf (0.17 MB)
#     ✓ Saved 02-12-2025-PD-Registro-Nacional-de-Turismo-RNT.pdf (0.48 MB)
#     ✓ Saved 26-11-2025-PD-restablecimiento-arancel-Decreto-272-del-13-de-febrero-de-2018.pdf (0.23 MB)
#     ✓ Saved 21-11-2025-PD-Acuerdo-sobre-Tecnologia-de-la-Informacion-ATI-de-la-OMC.pdf (0.23 MB)
#     ✓ Saved 21-11-2025-PD-modifica-en-lo-relativo-a-las-buenas-practicas-de-reglamentacion-tecnica.pdf (0.68 MB)
#     ✓ Saved 12-11-2025-PD-zonas-francas-permanentes-especiales-actividades-ferroviarias.pdf (0.27 MB)
#     ✓ Saved 12-11-2025-PD-incremento-aranceles-siderurgico.pdf (0.15 MB)
#     ✓ Saved 10-11-2025-PD-Modificacion-IAMAS.pdf (0.27 MB)
#     ✓ Saved 07-11-2025-PD-modifica-Arancel-Aduanas-Nacionales-importaciones-vehiculos-y-motos-gasolina-o-diesel.pdf (0.24 MB)
#     ✓ Saved 29-10-2025-PD-medidas-prevencion-y-control-fraude-aduanero-en-importaciones-arroces-semiblanqueados-o-blanqueados.pdf (0.26 MB)
#     ✓ Saved 21-10-2025-PD-Desdoblamiento-arancelario-CANNABIS-3A.pdf (0.25 MB)
#     ✓ Saved 10-10-2025-PD-nombramiento-y-remocion-SIC-SF-y-SS.pdf (0.25 MB)
#     ✓ Saved 23-09-2025-PD-Reversion-de-Pagos.pdf (0.28 MB)
#     ✓ Saved 19-09-2025-PD-composicion-del-Comite-Directivo-del-Fondo-Nacional-de-Turismo.pdf (0.32 MB)
#     ✓ Saved 15-09-2025-PD-modifica-arancel-aduanas-bieletas-estabilizadoras-de-suspension-de-vehiculos.pdf (0.22 MB)
#     ✓ Saved 15-09-2025-PD-aranceles-para-insumos-de-confecciones.pdf (0.14 MB)
#     ✓ Saved 09-09-2025-PD-aranceles-para-insumos-y-materias-primas-de-confecciones.pdf (0.39 MB)
#     ✓ Saved 21-08-2025-PD-Plan-Nacional-de-Desarrollo-2022-–-2026-compensaciones-industriales.pdf (0.28 MB)
#     ✓ Saved 08-08-2025-PD-Inclusion-de-Subpartida-como-Bien-de-Capital-SPC-CACN.pdf (0.14 MB)
#     ✓ Saved 08-08-2025-PD-deroga-Premio-Colombiano-a-la-Innovacion-Empresarial-para-las-MiPymes.pdf (0.17 MB)
#     ✓ Saved 08-08-2025-PD-control-del-fraude-aduanero-en-las-importaciones-de-hilos-de-coser.pdf (0.25 MB)
#     ✓ Saved 31-07-2025-PD-modifica-Arancel-de-Aduanas-importacion-insumos-agropecuarios.pdf (0.21 MB)
#     ✓ Saved 27-07-2025-PD-prohibicion-a-las-exportaciones-de-carbon-a-Israel.pdf (0.27 MB)
#     ✓ Saved 21-07-2025-PD-compensaciones-industriales-en-el-marco-de-la-Politica-de-Reindustrializacion.pdf (0.23 MB)
#     ✓ Saved 21-07-2025-PD-Arancel-Aduanas-importaciones-insumos-sector-confecciones-y-calzado.pdf (0.23 MB)
#     ✓ Saved 21-07-2025-PD-modifica-Decreto-2147-de-2016-Zonas-Francas-y-Economia-Popular.pdf (0.34 MB)
#     ✓ Saved 21-07-2025-PD-modifica-Arancel-Aduanas-importaciones-buses-electricos.pdf (0.23 MB)
#     ✓ Saved 21-07-2025-PD-modifica-parcialmente-Decreto-566-de-2025-CERT.pdf (0.14 MB)
#     ✓ Saved 04-07-2025-PD-reglamentacion-condiciones-y-requisitos-declaratoria-existencia-zonas-francas-permanentes-especiales-ferreas.pdf (0.44 MB)
#     ✓ Saved 02-07-2025-PD-ENMIENDAS-NIIF-y-NIIF-PYMES.pdf (0.37 MB)
#     ✓ Saved 18-06-2025-PD-contingente-para-las-exportaciones-de-desperdicios-y-desechos-de-chatarra.pdf (0.64 MB)
#     ✓ Saved 12-06-2025-PD-entrada-en-operacion-del-nuevo-patrimonio-autonomo-iNNpulsa-Colombia.pdf (0.25 MB)
#     ✓ Saved 04-06-2025-PD-reglamenta-el-articulo-86-de-la-Ley-2294-de-2023.pdf (0.25 MB)
#     ✓ Saved 01-06-2025-PD-Reglamenta-art-98-PND-11-04-2025.pdf (0.20 MB)
#     ✓ Saved 27-05-2025-PD-reglamenta-el-Decreto-Ley-1094-de-2024-CRIC.pdf (0.21 MB)
#     ✓ Saved 06-05-2025-PD-modifica-el-Decreto-2147-de-2016-zonas-francas.pdf (0.57 MB)
#     ✓ Saved 29-04-2025-PD-adiciona-un-paragrafo-al-articulo-70-del-Decreto-2147-de-2016.pdf (0.23 MB)
#     ✓ Saved 28-02-2025-PD-encargada-de-la-administracion-del-patrimonio-autonomo-INNpulsa.pdf (0.25 MB)
#     ✓ Saved 10-02-2025-PD-TLC-Colombia-y-Chile.pdf (0.31 MB)
#     ✓ Saved 24-01-2025-PD-Camara-de-comercio-de-Soacha-MODIF-22102023.pdf (0.23 MB)
#     ✓ Saved Proyecto-Decreto-Aranceles-Sector-Automotor.pdf (0.23 MB)
#   -> Manifest updated: data_raw\mincit\downloads_manifest.csv (+43 rows)
#
# --- PROCESS COMPLETED ---
# Total documents downloaded: 335
# Output folder: data_raw\mincit

# %% [markdown]
# #### Download Manifest Analysis and Annual File Size Aggregation
#
# The script loads the downloads_manifest.csv file with explicit typing and selected columns, filters out invalid records, and computes the total number of downloaded documents. It aggregates downloads by year to obtain annual counts and identifies, for each year, the largest file based on the bytes field, with an optional extraction of the top-N largest files per year.

# %%
import pandas as pd

# Define explicit data types to ensure memory efficiency and schema consistency
dtypes = {
    "saved_path": "string",
    "bytes": "Int64",
    "filename": "string",
    "source_url": "string",
    "year": "Int64",
    "landing_page": "string"
}

# Load only relevant columns from the downloads manifest
df = pd.read_csv(
    "legal-uncertainty-index/notebooks/downloads_manifest.csv",
    dtype=dtypes,
    usecols=["filename", "bytes", "year"]
)

# Remove records with missing year or file size information
df = df.dropna(subset=["year", "bytes"])

# Compute total number of valid downloaded documents
total_documents = len(df)
print(f"Total downloaded documents: {total_documents}")
# Out:
# Total downloaded documents: 334

# %%
# Compute the number of downloaded documents per year
documents_per_year = (
    df.groupby("year", observed=True)
      .size()
      .reset_index(name="num_documents")
      .sort_values("year")
)

print(documents_per_year)
# Out:
#    year  num_documents
# 0  2018             32
# 1  2019             63
# 2  2020             49
# 3  2021             51
# 4  2022             29
# 5  2023             32
# 6  2024             35
# 7  2025             43

# %%
# Identify the largest downloaded file (by size in bytes) for each year
idx = df.groupby("year")["bytes"].idxmax()

largest_file_per_year = (
    df.loc[idx, ["year", "filename", "bytes"]]
      .sort_values("year")
      .reset_index(drop=True)
)

print(largest_file_per_year)
# Out:
#    year                                           filename      bytes
# 0  2018                         image2019-02-25-104030.pdf    6244212
# 1  2019                            Proyecto-de-decreto.pdf    9048357
# 2  2020                      13-11-20-PD-ESTRUCTURA-SS.pdf   15255210
# 3  2021                       08-11-21-PD-VII-Enmienda.pdf  266375040
# 4  2022  18-02-2022-Proyecto-Decreto-Implementacion-tlc...    1329899
# 5  2023  29-08-2023-PD-Incorporacion-NIIF-17-contrato-d...    1033605
# 6  2024  10-05-2024-PD-Certificado-de-Reembolso-Tributa...    1131859
# 7  2025  21-11-2025-PD-modifica-en-lo-relativo-a-las-bu...     715439

# %%
# Retrieve the top N largest files per year based on file size
top_n = 3

top_n_files_per_year = (
    df.sort_values(["year", "bytes"], ascending=[True, False])
      .groupby("year")
      .head(top_n)
      .reset_index(drop=True)
)

print(top_n_files_per_year)
# Out:
#         bytes                                           filename  year
# 0     6244212                         image2019-02-25-104030.pdf  2018
# 1      777057                                      DECRETO-2.pdf  2018
# 2      637484                                     DECRETO-32.pdf  2018
# 3     9048357                            Proyecto-de-decreto.pdf  2019
# 4     1039000  Proyecto-decreto-desgravacion-arancelaria-TLC-...  2019
# 5      830956                        PytoD-ActualizacionD272.pdf  2019
# 6    15255210                      13-11-20-PD-ESTRUCTURA-SS.pdf  2020
# 7     5442937          26-06-20-Decreto-Astilleros-27jun2020.pdf  2020
# 8     3817223  31-08-20-PD-Trazabilidad-de-Alcohol-Potable-y-...  2020
# 9   266375040                       08-11-21-PD-VII-Enmienda.pdf  2021
# 10    9500587            17-11-21-PD-Derechos-Compensatorios.pdf  2021
# 11    5814224                                28-09-21-PD-RNT.pdf  2021
# 12    1329899  18-02-2022-Proyecto-Decreto-Implementacion-tlc...  2022
# 13     467067   20220330-PD-modificacion-Decreto-419-de-2021.pdf  2022
# 14     452933   14-02-2022-Proyecto-Decreto-Sello-Creo-en-Ti.pdf  2022
# 15    1033605  29-08-2023-PD-Incorporacion-NIIF-17-contrato-d...  2023
# 16     535632  30-10-2023-PD-Nuevo-modelo-tarifario-registro-...  2023
# 17     516086                           25-08-2023-PD-PROFIA.pdf  2023
# 18    1131859  10-05-2024-PD-Certificado-de-Reembolso-Tributa...  2024
# 19    1004852  26-12-2024-PD-reglamenta-el-Certificado-de-Ree...  2024
# 20     754428                           24-09-2024-PD-PROFIA.pdf  2024
# 21     715439  21-11-2025-PD-modifica-en-lo-relativo-a-las-bu...  2025
# 22     674602  18-06-2025-PD-contingente-para-las-exportacion...  2025
# 23     599917  06-05-2025-PD-modifica-el-Decreto-2147-de-2016...  2025

# %%
import os
from pathlib import Path

PROJECT_ROOT = Path(PROJECT_ROOT)
# Root directory containing yearly subfolders
DOWNLOAD_FOLDER = PROJECT_ROOT / "data_raw" / "mincit"

# Validate directory existence
if not DOWNLOAD_FOLDER.exists():
    raise FileNotFoundError(f"Download folder not found: {DOWNLOAD_FOLDER}")

pdf_counts = {}

# Iterate over year-level subdirectories
for subfolder in sorted(DOWNLOAD_FOLDER.iterdir()):
    if subfolder.is_dir():
        num_pdfs = len(list(subfolder.glob("*.pdf")))
        pdf_counts[subfolder.name] = num_pdfs

# Display results
for year, count in pdf_counts.items():
    print(f"{year}: {count} pdf")
# Out:
# 2018: 32 pdf
# 2019: 59 pdf
# 2020: 49 pdf
# 2021: 51 pdf
# 2022: 29 pdf
# 2023: 32 pdf
# 2024: 35 pdf
# 2025: 43 pdf
